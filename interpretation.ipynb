# %%
from keras.models import load_model
import tensorflow as tf
import numpy as np
import pickle as pkl

# %%
# currently 1 bi-directional lstm layer followed by a dense layer
class LSTM_network:

    def __init__(self, n_hidden, embedding_dim, n_classes, weights=None, debug=False):
        self.n_hidden = n_hidden
        self.embedding_dim = embedding_dim
        self.n_classes = n_classes
        self.debug = debug

        # model parameters
        if weights is not None:
            self.check_weights(weights)
            self.W_x_fward = tf.constant(weights[0], dtype=tf.float64)
            self.W_h_fward = tf.constant(weights[1], dtype=tf.float64)
            self.b_fward = tf.constant(weights[2], dtype=tf.float64)

            self.W_x_bward = tf.constant(weights[3], dtype=tf.float64)
            self.W_h_bward = tf.constant(weights[4], dtype=tf.float64)
            self.b_bward = tf.constant(weights[5], dtype=tf.float64)

            self.W_dense_fw = tf.constant(weights[6][:self.n_hidden], dtype=tf.float64)
            self.W_dense_bw = tf.constant(weights[6][self.n_hidden:], dtype=tf.float64)
            self.b_dense = tf.constant(weights[7], dtype=tf.float64)
        else:
            self.W_x_fward = tf.constant(np.random.randn(self.embedding_dim, 4 * self.n_hidden))
            self.W_h_fward = tf.constant(np.random.randn(self.n_hidden, 4 * self.n_hidden))
            self.b_fward = tf.constant(np.random.randn(4*self.n_hidden,))

            self.W_x_bward = tf.constant(np.random.randn(self.embedding_dim, 4 * self.n_hidden))
            self.W_h_bward = tf.constant(np.random.randn(self.n_hidden, 4 * self.n_hidden))
            self.b_bward = tf.constant(np.random.randn(4 * self.n_hidden, ))

            self.W_dense_fw = tf.constant(np.random.randn(n_hidden, n_classes))
            self.W_dense_bw = tf.constant(np.random.randn(n_hidden, n_classes))
            self.b_dense = tf.constant(np.random.randn(n_classes))

        # prediction of the net
        self.y_hat = tf.Variable(0., shape=tf.TensorShape(None), dtype=tf.float64, name='y_hat')

        # the following order is from keras. You might have to adjust it if you use different frameworks
        self.idx_i = slice(0, self.n_hidden)
        self.idx_f = slice(self.n_hidden, 2 * self.n_hidden)
        self.idx_c = slice(2 * self.n_hidden, 3 * self.n_hidden)
        self.idx_o = slice(3 * self.n_hidden, 4 * self.n_hidden)

    def check_weights(self, weights):
        assert len(weights) == 8
        assert weights[0].shape == weights[3].shape == (self.embedding_dim, 4 * self.n_hidden)
        assert weights[1].shape == weights[4].shape == (self.n_hidden, 4 * self.n_hidden)
        assert weights[2].shape == weights[5].shape == (4 * self.n_hidden, )
        assert weights[6].shape == (2 * self.n_hidden, self.n_classes)
        assert weights[7].shape == (self.n_classes,)

    # x is batch of embedding vectors (batch_size, embedding_dim)
    @tf.function
    def cell_step(self, x, h_old, c_old, W_x, W_h, b):
        # fward pass
        gate_x = tf.matmul(x, W_x)
        gate_h = tf.matmul(h_old, W_h)
        gate_pre = gate_x + gate_h + b
        gate_post = tf.concat([
                            tf.sigmoid(gate_pre[:, self.idx_i]), tf.sigmoid(gate_pre[:, self.idx_f]),
                            tf.tanh(gate_pre[:, self.idx_c]), tf.sigmoid(gate_pre[:, self.idx_o]),
                            ], axis=1)
        c_new = gate_post[:, self.idx_f] * c_old + gate_post[:, self.idx_i] * gate_post[:, self.idx_c]
        h_new = gate_post[:, self.idx_o] * tf.tanh(c_new)
        return gate_pre, gate_post, c_new, h_new

    # x is batch of embedding vectors (batch_size, embedding_dim)
    @tf.function
    def one_step_fward(self, x, h_old_fw, c_old_fw):
        fward = self.cell_step(x, h_old_fw, c_old_fw, self.W_x_fward, self.W_h_fward, self.b_fward)
        return fward

    # x_rev is batch of embedding vectors (batch_size, embedding_dim)
    @tf.function
    def one_step_bward(self, x_rev, h_old_bw, c_old_bw):
        bward = self.cell_step(x_rev, h_old_bw, c_old_bw, self.W_x_bward, self.W_h_bward, self.b_bward)
        return bward

    # input is full batch (batch_size, T, embedding_dim)
    @tf.function(experimental_relax_shapes=True)
    def full_pass(self, x):
        assert len(x.shape) == 3, '3 dimensional input required, got input of len {}'.format(len(x.shape))
        batch_size = x.shape[0]
        # we have to reorder the input since tf.scan scans the input along the first axis
        elems = tf.transpose(x, perm=[1,0,2])
        initializer = (tf.constant(np.zeros((batch_size, 4 * self.n_hidden))),  # gates_pre
                       tf.constant(np.zeros((batch_size, 4 * self.n_hidden))),  # gates_post
                       tf.constant(np.zeros((batch_size, self.n_hidden))),      # c_t
                       tf.constant(np.zeros((batch_size, self.n_hidden))))      # h_t
        fn_fward = lambda a, x: self.one_step_fward(x, a[3], a[2])
        fn_bward = lambda a, x: self.one_step_bward(x, a[3], a[2])
        # outputs contain tesnors with (T, gates_pre, gates_post, c,h)
        o_fward = tf.scan(fn_fward, elems, initializer=initializer)
        o_bward = tf.scan(fn_bward, elems, initializer=initializer, reverse=True)
        # final prediction scores
        y_fward = tf.matmul(o_fward[3][-1], self.W_dense_fw)
        y_bward = tf.matmul(o_bward[3][0], self.W_dense_bw)
        y_hat = y_fward + y_bward + self.b_dense
        self.y_hat.assign(y_hat)
        return y_hat, o_fward, o_bward

    def lrp_linear_layer(self, h_in, w, b, hout, Rout, bias_nb_units, eps, bias_factor=0.0):
        """
        LRP for a linear layer with input dim D and output dim M.
        Args:
        - hin:            forward pass input, of shape (batch_size, D)
        - w:              connection weights, of shape (D, M)
        - b:              biases, of shape (M,)
        - hout:           forward pass output, of shape (batch_size, M) (unequal to np.dot(w.T,hin)+b if more than
                          one incoming layer!)
        - Rout:           relevance at layer output, of shape (batch_size, M)
        - bias_nb_units:  total number of connected lower-layer units (onto which the bias/stabilizer contribution
                          is redistributed for sanity check)
        - eps:            stabilizer (small positive number)
        - bias_factor:    set to 1.0 to check global relevance conservation, otherwise use 0.0 to ignore
                          bias/stabilizer redistribution (recommended)
        Returns:
        - Rin:            relevance at layer input, of shape (batch_size, D)
        """
        bias_factor_t = tf.constant(bias_factor, dtype=tf.float64)
        eps_t = tf.constant(eps, dtype=tf.float64)
        sign_out = tf.cast(tf.where(hout >= 0, 1., -1.), tf.float64)   # shape (batch_size, M)
        numerator_1 = tf.expand_dims(h_in, axis=2) * w
        numerator_2 = bias_factor_t * (tf.expand_dims(b, 0) + eps_t * sign_out) / bias_nb_units
        # use the following term if you want to check relevance property
        #numerator_2 =  (bias_factor_t * tf.expand_dims(b, 0) + eps_t * sign_out) / bias_nb_units
        numerator = numerator_1 + tf.expand_dims(numerator_2, 1)
        denom = hout + (eps*sign_out)
        message = numerator / tf.expand_dims(denom, 1) * tf.expand_dims(Rout, 1)
        R_in = tf.reduce_sum(message, axis=2)
        return R_in

    def lrp(self, x, y=None, eps=1e-3, bias_factor=0.0):
        """
        LRP for a batch of samples x.
        Args:
        - x:              input array. dim = (batch_size, T, embedding_dim)
        - y:              desired output_class to explain. dim = (batch_size,)
        - eps:            eps value for lrp-eps
        - bias_factor:    bias factor for lrp
        Returns:
        - Relevances:     relevances of each input dimension. dim = (batch_size, T, embedding_dim
        """
        assert len(x.shape) == 3, '3 dimensional input required, got input of len {}'.format(len(x.shape))
        lrp_pass = self.lrp_lstm(x,y,eps, bias_factor)
        # add forward and backward relevances of x.
        # Here we have to reverse R_x_fw since the tf.scan() function starts at the last timestep (T-1) and moves to
        # timestep 0. Therefore the last entry of lrp_pass[2] belongs to the first timestep of x. Likewise, the last
        # entry of lrp_pass[5] (R_x_rev) belongs to the last timestep of x and is thus already in the right order.
        Rx_ = tf.reverse(lrp_pass[2], axis=[0]) + lrp_pass[5]
        Rx = tf.transpose(Rx_, perm=(1,0,2))  # put batch dimension to first dim again
        # remaining relevance is sum of last entry of Rh and Rc
        rest = tf.reduce_sum(lrp_pass[0][-1] + lrp_pass[1][-1] + lrp_pass[3][-1] + lrp_pass[4][-1], axis=1)
        return Rx, rest

    @tf.function
    def lrp_lstm(self, x, y=None, eps=1e-3, bias_factor=0.0):
        batch_size = x.shape[0]
        T = x.shape[1]
        x_rev = tf.reverse(x, axis=[1])
        # update inner states
        y_hat, output_fw, output_bw = self.full_pass(x)
        # if classes are given, use them. Else choose prediction of the network
        if y is not None:
            assert y.shape == (batch_size, )
            if not y.dtype is tf.int64:
                y = tf.cast(y, tf.int64)
            R_out_mask = tf.one_hot(y, depth=self.n_classes, dtype=tf.float64)
        else:
            R_out_mask = tf.one_hot(tf.argmax(y_hat, axis=1), depth=self.n_classes, dtype=tf.float64)
        R_T = y_hat * R_out_mask
        gates_pre_fw, gates_post_fw, c_fw, h_fw = output_fw
        gates_pre_bw, gates_post_bw, c_bw, h_bw = output_bw
        # c and h have one timestep more than x (the initial one, we have to add these zeros manually)
        zero_block = tf.constant(np.zeros((1, batch_size, self.n_hidden)))
        c_fw = tf.concat([c_fw, zero_block], axis=0)
        h_fw = tf.concat([h_fw, zero_block], axis=0)
        gates_pre_bw = tf.reverse(gates_pre_bw, [0])
        gates_post_bw = tf.reverse(gates_post_bw, [0])
        c_bw = tf.reverse(c_bw, [0])
        h_bw = tf.reverse(h_bw, [0])
        c_bw = tf.concat([c_bw, zero_block], axis=0)
        h_bw = tf.concat([h_bw, zero_block], axis=0)

        # first calculate relevaces from final linear layer
        Rh_fw_T = self.lrp_linear_layer(h_fw[T - 1], self.W_dense_fw, self.b_dense,
                                       y_hat, R_T, 2*self.n_hidden, eps, bias_factor)
        Rh_bw_T = self.lrp_linear_layer(h_bw[T - 1], self.W_dense_bw, self.b_dense,
                                       y_hat, R_T, 2*self.n_hidden, eps, bias_factor)
        if self.debug:
            tf.print('Dense: Input relevance', tf.reduce_sum(R_T, axis=1))
            tf.print('Dense: Output relevance', tf.reduce_sum(Rh_fw_T+Rh_bw_T, axis=1))
        elems = np.arange(T-1, -1, -1)
        initializer = (
                       Rh_fw_T,                                                                     # R_h_fw
                       Rh_fw_T,                                                                     # R_c_fw
                       tf.constant(np.zeros((batch_size, self.embedding_dim)), name='R_x_fw'),      # R_x_fw
                       Rh_bw_T,                                                                     # R_h_bw
                       Rh_bw_T,                                                                     # R_c_bw
                       tf.constant(np.zeros((batch_size, self.embedding_dim)), name='R_x_bw')       # R_x_bw
                       )
        eye = tf.eye(self.n_hidden, dtype=tf.float64)
        zeros_hidden = tf.constant(np.zeros((self.n_hidden)))

        @tf.function
        def update(input_tuple, t):
            # t starts with T-1 ; the values we want to update are essentially Rh, Rc and Rx
            # input_tuple is (R_h_fw_t+1, R_c_fw_t+1, R_x_fw_t+1, R_h_bw_t+1, R_h_bw_t+1, R_x_bw_t+1)
            #forward
            Rc_fw_t = self.lrp_linear_layer(gates_post_fw[t, :, self.idx_f] * c_fw[t-1, :], eye, zeros_hidden,
                                               c_fw[t, :],  input_tuple[1], 2*self.n_hidden, eps, bias_factor)
            R_g_fw = self.lrp_linear_layer(gates_post_fw[t,:,self.idx_i] * gates_post_fw[t,:,self.idx_c], eye,
                                        zeros_hidden, c_fw[t, :], input_tuple[1], 2*self.n_hidden, eps, bias_factor)
            if self.debug:
                tf.print('Fw1: Input relevance', tf.reduce_sum(input_tuple[1], axis=1))
                tf.print('Fw1: Output relevance', tf.reduce_sum(Rc_fw_t + R_g_fw, axis=1))
            Rx_t = self.lrp_linear_layer(x[:,t], self.W_x_fward[:, self.idx_c], self.b_fward[self.idx_c],
                                         gates_pre_fw[t, :, self.idx_c], R_g_fw, self.n_hidden + self.embedding_dim, eps, bias_factor)
            Rh_fw_t = self.lrp_linear_layer(h_fw[t-1, :], self.W_h_fward[:, self.idx_c], self.b_fward[self.idx_c],
                                            gates_pre_fw[t, :, self.idx_c], R_g_fw, self.n_hidden + self.embedding_dim, eps, bias_factor
                                            )
            if self.debug:
                tf.print('Fw2: Input relevance', tf.reduce_sum(R_g_fw, axis=1))
                tf.print('Fw2: Output relevance', tf.reduce_sum(Rx_t,axis=1)+tf.reduce_sum(Rh_fw_t, axis=1))
            if t != 0:
                Rc_fw_t += Rh_fw_t
            #backward
            Rc_bw_t = self.lrp_linear_layer(gates_post_bw[t, :, self.idx_f] * c_bw[t-1, :], eye, zeros_hidden,
                                            c_bw[t, :], input_tuple[4], 2*self.n_hidden, eps, bias_factor)
            R_g_bw = self.lrp_linear_layer(gates_post_bw[t, :, self.idx_i] * gates_post_bw[t, :, self.idx_c], eye,
                                           zeros_hidden, c_bw[t,:], input_tuple[4], 2*self.n_hidden, eps, bias_factor)
            if self.debug:
                tf.print('Bw1: Input relevance', tf.reduce_sum(input_tuple[4], axis=1))
                tf.print('Bw1: Output relevance', tf.reduce_sum(Rc_bw_t + R_g_bw, axis=1))
            Rx_rev_t = self.lrp_linear_layer(x_rev[:, t], self.W_x_bward[:, self.idx_c], self.b_bward[self.idx_c],
                                            gates_pre_bw[t, :, self.idx_c], R_g_bw, self.n_hidden + self.embedding_dim, eps, bias_factor)
            Rh_bw_t = self.lrp_linear_layer(h_bw[t-1, :], self.W_h_bward[:, self.idx_c], self.b_bward[self.idx_c],
                                            gates_pre_bw[t, :, self.idx_c], R_g_bw, self.n_hidden + self.embedding_dim, eps, bias_factor
                                            )
            if self.debug:
                tf.print('Bw2: Input relevance', tf.reduce_sum(R_g_bw, axis=1))
                tf.print('Bw2: Output relevance', tf.reduce_sum(Rx_rev_t,axis=1)+tf.reduce_sum(Rh_bw_t, axis=1))
            if t != 0:
                Rc_bw_t += Rh_bw_t
            return Rh_fw_t, Rc_fw_t, Rx_t, Rh_bw_t, Rc_bw_t, Rx_rev_t

        lrp_pass = tf.scan(update, elems, initializer)
        return lrp_pass

# %%
# load the keras model and the word-2-vec dictionary. The keras model is trained for the sentiment analysis dataset
# from stanford university and classifies movie reviews into five different categories.
keras_model = load_model('../input/reference-model/sentiment_model.hdf5')
w2v = pkl.load(open('../input/reference-model/token2vec.pkl', 'rb'))
# create the lstm-lrp model
n_hidden = 60
embedding_dim = 60
n_classes = 5
weights = keras_model.get_weights()
print(len(weights))
# our keras model has no bias in the final dense layer. Therefore we add a bias of zero to the weights
weights.append(np.zeros((n_classes,)))
lrp_model = LSTM_network(n_hidden, embedding_dim, n_classes, weights=weights)
# Out:
# 7

# %%
import codecs
def get_test_sentence(sent_idx):
    """Returns an SST test set sentence and its true label, sent_idx must be an integer in [1, 2210]"""
    idx = 1
    with codecs.open("./data/sequence_test.txt", 'r', encoding='utf8') as f:
        for line in f:
            line          = line.rstrip('\n')
            line          = line.split('\t')
            true_class    = int(line[0])-1         # true class
            words         = line[1].split(' | ')   # sentence as list of words
            if idx == sent_idx:
                return words, true_class
            idx +=1
def get_all_test_sentence():
    res = []
    with codecs.open("../input/sentence-test/sequence_test.txt", 'r', encoding='utf8') as f:
        for line in f:
            line          = line.rstrip('\n')
            line          = line.split('\t')
            true_class    = int(line[0])-1         # true class
            words         = line[1].split(' | ')   # sentence as list of words
            res.append((true_class, words))
    return res

# %%
# # for practical example
# eps = 1e-3
# bias_factor = 0.0
# sentence = 'all but the most persnickety preteens should enjoy this nonthreatening but thrilling adventure .'

# # test if the conversion was correct with an example sentence
# # sentence = 'Neither funny nor suspenseful nor particularly well-drawn .'
# tokens = [s.lower() for s in sentence.split()]
# vecs = np.array([w2v[t] for t in tokens])
# y_keras = keras_model.predict(vecs[np.newaxis,:])
# model_prediction_class = np.argmax(y_keras[0])

# # by setting y=None, the relevances will be calculated for the predicted class of the sample. We recommend this
# # usage, however, if you are interested in the relevances towards the 1st class, you could use y = np.array([1])
# explanation, Rest = lrp_model.lrp(vecs[np.newaxis,:], eps=eps, bias_factor=bias_factor)
# # LRP assigns each dimension in the embedding vector a relevance value. To get relevances for each word we can
# # sum up these values
# relevance_list = tf.reduce_sum(explanation, axis=2)[0]
# index_list = sorted(range(len(relevance_list)), key=lambda k: relevance_list[k], reverse=True)
# weighted_score = np.array([0, 0, 0, 0, 0])
# most_related_contribution = np.array([0, 0, 0, 0, 0])
# fine_tuning = np.array([0, 0, 0, 0, 0])
# for index in index_list:
#     word = tokens[index]
#     vecs = np.array([w2v[t] for t in [word]])
#     single_prediction_class = np.argmax(keras_model.predict(vecs[np.newaxis,:])[0])
#     new = np.array([0, 0, 0, 0, 0])
#     new[single_prediction_class] = 1
#     relevance = relevance_list[index]
#     print('word: {}, score: {}'.format(word, new))
#     print('{0:>13}:   {1:8.2f}'.format(word, relevance))
#     contribution_score = relevance*new
#     print('{}:   {}'.format(word, contribution_score))
#     weighted_score = np.sum([weighted_score, contribution_score], axis=0)
#     if index == index_list[0]:
#         most_related_contribution = contribution_score
# most_related_prediction_class = np.argmax(most_related_contribution)
# weighted_prediction_class = np.argmax(weighted_score)
# if (weighted_prediction_class == 0 and most_related_prediction_class == 1) or  (weighted_prediction_class == 4 and most_related_prediction_class == 3):
#     lrp_class = weighted_prediction_class
# else:
#     lrp_class = most_related_prediction_class

# print('most_related_contribution:{}'.format(most_related_contribution))
# print('most_related_prediction_class:{}'.format(most_related_prediction_class))
# print('weighted_score:{}'.format(weighted_score))
# print('weighted_prediction_class:{}'.format(weighted_prediction_class))
# print('lrp prediction class:{}'.format(weighted_prediction_class))

# %%
# calculate the recall and precision.'
eps = 1e-3
bias_factor = 0.0
weighted_correct_count = 0
weighted_n_to_p = 0
weighted_p_to_n = 0
weighted_neutral_floating_1 = 0
most_related_correct_count = 0
most_related_n_to_p = 0
most_related_p_to_n = 0
most_related_neutral_floating_1 = 0


zero_to_zero = 0
zero_to_one = 0
zero_to_two = 0
zero_to_three = 0
zero_to_four = 0

one_to_zero = 0
one_to_one = 0
one_to_two = 0
one_to_three = 0
one_to_four = 0


two_to_zero = 0
two_to_one = 0
two_to_two = 0
two_to_three = 0
two_to_four = 0


three_to_zero = 0
three_to_one = 0
three_to_two = 0
three_to_three = 0
three_to_four = 0

four_to_zero = 0
four_to_one = 0
four_to_two = 0
four_to_three = 0
four_to_four = 0

floating_correct_count = 0
floating_n_to_p = 0
floating_p_to_n = 0
floating_neutral_floating_1 = 0

res = get_all_test_sentence()
for i in range(2210):
    true_class, words = res[i]
    tokens = [s.lower() for s in words]
    vecs = np.array([w2v[t] for t in tokens])
    y_keras = keras_model.predict(vecs[np.newaxis,:])
    model_prediction_class = np.argmax(y_keras[0])

    # by setting y=None, the relevances will be calculated for the predicted class of the sample. We recommend this
    # usage, however, if you are interested in the relevances towards the 1st class, you could use y = np.array([1])
    explanation, Rest = lrp_model.lrp(vecs[np.newaxis,:], eps=eps, bias_factor=bias_factor)
    # LRP assigns each dimension in the embedding vector a relevance value. To get relevances for each word we can
    # sum up these values
    relevance_list = tf.reduce_sum(explanation, axis=2)[0]
    index_list = sorted(range(len(relevance_list)), key=lambda k: relevance_list[k], reverse=True)
    weighted_score = np.array([0, 0, 0, 0, 0])
    most_related_contribution = np.array([0, 0, 0, 0, 0])
    fine_tuning = np.array([0, 0, 0, 0, 0])
    for index in index_list:
        word = tokens[index]
        vecs = np.array([w2v[t] for t in [word]])
        single_prediction_class = np.argmax(keras_model.predict(vecs[np.newaxis,:])[0])
        new = np.array([0, 0, 0, 0, 0])
        new[single_prediction_class] = 1
        relevance = relevance_list[index]
        print('word: {}, score: {}'.format(word, new))
        print('{0:>13}:   {1:8.2f}'.format(word, relevance))
        contribution_score = relevance*new
        weighted_score = np.sum([weighted_score, contribution_score], axis=0)
        if index == index_list[0]:
            most_related_contribution = contribution_score
    most_related_prediction_class = np.argmax(most_related_contribution)
    weighted_prediction_class = np.argmax(weighted_score)
    
    
    if (weighted_prediction_class == 0 and most_related_prediction_class == 1) or  (weighted_prediction_class == 4 and most_related_prediction_class == 3):
        lrp_class = weighted_prediction_class
    else:
        lrp_class = most_related_prediction_class
            
    if model_prediction_class == 0:
        if weighted_prediction_class == 0:
            zero_to_zero += 1
        elif weighted_prediction_class == 1:
            zero_to_one += 1
        elif weighted_prediction_class == 2:
            zero_to_two += 1
        elif weighted_prediction_class == 3:
            zero_to_three += 1
        elif weighted_prediction_class == 4:
            zero_to_four += 1
    elif model_prediction_class == 1:
        if weighted_prediction_class == 0:
            one_to_zero += 1
        elif weighted_prediction_class == 1:
            one_to_one += 1
        elif weighted_prediction_class == 2:
            one_to_two += 1
        elif weighted_prediction_class == 3:
            one_to_three += 1
        elif weighted_prediction_class == 4:
            one_to_four += 1
    elif model_prediction_class == 2:
        if weighted_prediction_class == 0:
            two_to_zero += 1
        elif weighted_prediction_class == 1:
            two_to_one += 1
        elif weighted_prediction_class == 2:
            two_to_two += 1
        elif weighted_prediction_class == 3:
            two_to_three += 1
        elif weighted_prediction_class == 4:
            two_to_four += 1
    elif model_prediction_class == 3:
        if weighted_prediction_class == 0:
            three_to_zero += 1
        elif weighted_prediction_class == 1:
            three_to_one += 1
        elif weighted_prediction_class == 2:
            three_to_two += 1
        elif weighted_prediction_class == 3:
            three_to_three += 1
        elif weighted_prediction_class == 4:
            three_to_four += 1
    elif model_prediction_class == 4:
        if weighted_prediction_class == 0:
            four_to_zero += 1
        elif weighted_prediction_class == 1:
            four_to_one += 1
        elif weighted_prediction_class == 2:
            four_to_two += 1
        elif weighted_prediction_class == 3:
            four_to_three += 1
        elif weighted_prediction_class == 4:
            four_to_four += 1
    


        
        
#     if model_prediction_class == 0:
#         if weighted_prediction_class == 0:
#             zero_to_zero += 1
#         elif weighted_prediction_class == 1:
#             zero_to_one += 1
#         elif weighted_prediction_class == 2:
#             zero_to_two += 1
#         elif weighted_prediction_class == 3:
#             zero_to_three += 1
#         elif weighted_prediction_class == 4:
#             zero_to_four += 1
#     elif model_prediction_class == 1:
#         if weighted_prediction_class == 0:
#             one_to_zero += 1
#         elif weighted_prediction_class == 1:
#             one_to_one += 1
#         elif weighted_prediction_class == 2:
#             one_to_two += 1
#         elif weighted_prediction_class == 3:
#             one_to_three += 1
#         elif weighted_prediction_class == 4:
#             one_to_four += 1
#     elif model_prediction_class == 2:
#         if weighted_prediction_class == 0:
#             two_to_zero += 1
#         elif weighted_prediction_class == 1:
#             two_to_one += 1
#         elif weighted_prediction_class == 2:
#             two_to_two += 1
#         elif weighted_prediction_class == 3:
#             two_to_three += 1
#         elif weighted_prediction_class == 4:
#             two_to_four += 1
#     elif model_prediction_class == 3:
#         if weighted_prediction_class == 0:
#             three_to_zero += 1
#         elif weighted_prediction_class == 1:
#             three_to_one += 1
#         elif weighted_prediction_class == 2:
#             three_to_two += 1
#         elif weighted_prediction_class == 3:
#             three_to_three += 1
#         elif weighted_prediction_class == 4:
#             three_to_four += 1
#     elif model_prediction_class == 4:
#         if weighted_prediction_class == 0:
#             four_to_zero += 1
#         elif weighted_prediction_class == 1:
#             four_to_one += 1
#         elif weighted_prediction_class == 2:
#             four_to_two += 1
#         elif weighted_prediction_class == 3:
#             four_to_three += 1
#         elif weighted_prediction_class == 4:
#             four_to_four += 1
        
#     if model_prediction_class == 0:
#         if most_related_prediction_class == 0:
#             zero_to_zero += 1
#         elif most_related_prediction_class == 1:
#             zero_to_one += 1
#         elif most_related_prediction_class == 2:
#             zero_to_two += 1
#         elif most_related_prediction_class == 3:
#             zero_to_three += 1
#         elif most_related_prediction_class == 4:
#             zero_to_four += 1
#     elif model_prediction_class == 1:
#         if most_related_prediction_class == 0:
#             one_to_zero += 1
#         elif most_related_prediction_class == 1:
#             one_to_one += 1
#         elif most_related_prediction_class == 2:
#             one_to_two += 1
#         elif most_related_prediction_class == 3:
#             one_to_three += 1
#         elif most_related_prediction_class == 4:
#             one_to_four += 1
#     elif model_prediction_class == 2:
#         if most_related_prediction_class == 0:
#             two_to_zero += 1
#         elif most_related_prediction_class == 1:
#             two_to_one += 1
#         elif most_related_prediction_class == 2:
#             two_to_two += 1
#         elif most_related_prediction_class == 3:
#             two_to_three += 1
#         elif most_related_prediction_class == 4:
#             two_to_four += 1
#     elif model_prediction_class == 3:
#         if most_related_prediction_class == 0:
#             three_to_zero += 1
#         elif most_related_prediction_class == 1:
#             three_to_one += 1
#         elif most_related_prediction_class == 2:
#             three_to_two += 1
#         elif most_related_prediction_class == 3:
#             three_to_three += 1
#         elif most_related_prediction_class == 4:
#             three_to_four += 1
#     elif model_prediction_class == 4:
#         if most_related_prediction_class == 0:
#             four_to_zero += 1
#         elif most_related_prediction_class == 1:
#             four_to_one += 1
#         elif most_related_prediction_class == 2:
#             four_to_two += 1
#         elif most_related_prediction_class == 3:
#             four_to_three += 1
#         elif most_related_prediction_class == 4:
#             four_to_four += 1
    
# # #     if true_class == 0:
# # #         if model_prediction_class == 0:
# # #             zero_to_zero += 1
# # #         elif model_prediction_class == 1:
# # #             zero_to_one += 1
# # #         elif model_prediction_class == 2:
# # #             zero_to_two += 1
# # #         elif model_prediction_class == 3:
# # #             zero_to_three += 1
# # #         elif model_prediction_class == 4:
# # #             zero_to_four += 1
# # #     elif true_class == 1:
# # #         if model_prediction_class == 0:
# # #             one_to_zero += 1
# # #         elif model_prediction_class == 1:
# # #             one_to_one += 1
# # #         elif model_prediction_class == 2:
# # #             one_to_two += 1
# # #         elif model_prediction_class == 3:
# # #             one_to_three += 1
# # #         elif model_prediction_class == 4:
# # #             one_to_four += 1
# # #     elif true_class == 2:
# # #         if model_prediction_class == 0:
# # #             two_to_zero += 1
# # #         elif model_prediction_class == 1:
# # #             two_to_one += 1
# # #         elif model_prediction_class == 2:
# # #             two_to_two += 1
# # #         elif model_prediction_class == 3:
# # #             two_to_three += 1
# # #         elif model_prediction_class == 4:
# # #             two_to_four += 1
# # #     elif true_class == 3:
# # #         if model_prediction_class == 0:
# # #             three_to_zero += 1
# # #         elif model_prediction_class == 1:
# # #             three_to_one += 1
# # #         elif model_prediction_class == 2:
# # #             three_to_two += 1
# # #         elif model_prediction_class == 3:
# # #             three_to_three += 1
# # #         elif model_prediction_class == 4:
# # #             three_to_four += 1
# # #     elif true_class == 4:
# # #         if model_prediction_class == 0:
# # #             four_to_zero += 1
# # #         elif model_prediction_class == 1:
# # #             four_to_one += 1
# # #         elif model_prediction_class == 2:
# # #             four_to_two += 1
# # #         elif model_prediction_class == 3:
# # #             four_to_three += 1
# # #         elif model_prediction_class == 4:
# # #             four_to_four += 1
    if weighted_prediction_class == model_prediction_class:
        weighted_correct_count += 1
    elif weighted_prediction_class in (3, 4) and model_prediction_class in (0, 1):
        weighted_n_to_p += 1
    elif weighted_prediction_class in (0, 1) and model_prediction_class in (3, 4):
        weighted_p_to_n += 1
    elif model_prediction_class == 2 and abs(weighted_prediction_class - model_prediction_class) ==1:
        weighted_neutral_floating_1 += 1
    

print('zero_to_zero:{}'.format(zero_to_zero))
print('zero_to_one:{}'.format(zero_to_one))
print('zero_to_two:{}'.format(zero_to_two))
print('zero_to_three:{}'.format(zero_to_three))
print('zero_to_four:{}'.format(zero_to_four))

print('one_to_zero:{}'.format(one_to_zero))
print('one_to_one:{}'.format(one_to_one))
print('one_to_two:{}'.format(one_to_two))
print('one_to_three:{}'.format(one_to_three))
print('one_to_four:{}'.format(one_to_four))


print('two_to_zero:{}'.format(two_to_zero))
print('two_to_one:{}'.format(two_to_one))
print('two_to_two:{}'.format(two_to_two))
print('two_to_three:{}'.format(two_to_three))
print('two_to_four:{}'.format(two_to_four))


print('three_to_zero:{}'.format(three_to_zero))
print('three_to_one:{}'.format(three_to_one))
print('three_to_two:{}'.format(three_to_two))
print('three_to_three:{}'.format(three_to_three))
print('three_to_four:{}'.format(three_to_four))

print('four_to_zero:{}'.format(four_to_zero))
print('four_to_one:{}'.format(four_to_one))
print('four_to_two:{}'.format(four_to_two))
print('four_to_three:{}'.format(four_to_three))
print('four_to_four:{}'.format(four_to_four))
        
print('weighted_correct_count:{}'.format(weighted_correct_count))
print('weighted_n_to_p:{}'.format(weighted_n_to_p))
print('weighted_p_to_n:{}'.format(weighted_p_to_n))
print('weighted_neutral_floating_1:{}'.format(weighted_neutral_floating_1))
# # # print('most_related_correct_count:{}'.format(most_related_correct_count))
# # # print('most_related_n_to_p:{}'.format(most_related_n_to_p))
# # # print('most_related_p_to_n:{}'.format(most_related_p_to_n))
# # # print('most_related_neutral_floating_1:{}'.format(most_related_neutral_floating_1))
# Out:
# word: ridiculous, score: [0 1 0 0 0]
#    ridiculous:       4.32
# word: ., score: [0 0 1 0 0]
#             .:      -0.05
# word: ., score: [0 0 1 0 0]
#             .:       0.01
# word: hopkins, score: [0 0 0 1 0]
#       hopkins:      -0.16
# word: brimful, score: [0 0 1 0 0]
#       brimful:       0.14
# word: ., score: [0 0 1 0 0]
#             .:      -0.02
# word: hmm, score: [0 0 1 0 0]
#           hmm:       0.04
# word: ., score: [0 0 1 0 0]
#             .:      -0.02
# word: immediately, score: [0 0 1 0 0]
#   immediately:       0.53
# word: ., score: [0 0 1 0 0]
#             .:      -0.06
# word: ., score: [0 0 1 0 0]
#             .:       0.00
# word: no., score: [0 1 0 0 0]
#           no.:      -0.13
# word: boring, score: [1 0 0 0 0]
#        boring:       4.20
# word: extremely, score: [0 0 1 0 0]
#     extremely:       1.00
# word: ., score: [0 0 1 0 0]
#             .:      -0.01
# word: confusing, score: [0 1 0 0 0]
#     confusing:       1.99
# word: extremely, score: [0 0 1 0 0]
#     extremely:       0.85
# word: ., score: [0 0 1 0 0]
#             .:      -0.13
# word: dumb, score: [0 1 0 0 0]
#          dumb:       4.16
# word: extremely, score: [0 0 1 0 0]
#     extremely:       0.92
# word: ., score: [0 0 1 0 0]
#             .:       0.03
# word: deal, score: [0 0 1 0 0]
#          deal:       0.92
# word: !, score: [0 0 1 0 0]
#             !:       0.80
# word: big, score: [0 0 1 0 0]
#           big:       0.23
# word: point, score: [0 0 1 0 0]
#         point:       0.26
# word: moot, score: [0 0 1 0 0]
#          moot:      -0.09
# word: ., score: [0 0 1 0 0]
#             .:      -0.40
# word: no, score: [0 1 0 0 0]
#            no:       1.22
# word: more, score: [0 0 1 0 0]
#          more:       0.13
# word: ., score: [0 0 1 0 0]
#             .:      -0.22
# word: sorry, score: [0 1 0 0 0]
#         sorry:       1.64
# word: charlie, score: [0 0 1 0 0]
#       charlie:      -0.03
# word: ,, score: [0 0 1 0 0]
#             ,:      -0.08
# word: ?, score: [0 0 1 0 0]
#             ?:       1.34
# word: anthony, score: [0 0 1 0 0]
#       anthony:       0.13
# word: hopkins, score: [0 0 0 1 0]
#       hopkins:       0.06
# word: good, score: [0 0 0 1 0]
#          good:       3.16
# word: ., score: [0 0 1 0 0]
#             .:       0.20
# word: actress, score: [0 0 1 0 0]
#       actress:      -0.42
# word: good, score: [0 0 0 1 0]
#          good:       3.27
# word: movie, score: [0 0 1 0 0]
#         movie:       1.08
# word: ., score: [0 0 1 0 0]
#             .:       0.73
# word: no, score: [0 1 0 0 0]
#            no:       0.57
# word: question, score: [0 0 1 0 0]
#      question:       0.40
# word: ., score: [0 0 1 0 0]
#             .:       0.09
# word: brilliant, score: [0 0 0 0 1]
#     brilliant:       6.38
# word: !, score: [0 0 1 0 0]
#             !:       1.82
# word: ', score: [0 0 1 0 0]
#             ':      -0.06
# word: you, score: [0 0 1 0 0]
#           you:       0.60
# word: bet, score: [0 0 1 0 0]
#           bet:       0.09
# word: ., score: [0 0 1 0 0]
#             .:       0.05
# word: clunker, score: [0 1 0 0 0]
#       clunker:       2.13
# word: a, score: [0 0 1 0 0]
#             a:      -0.15
# word: ., score: [0 0 1 0 0]
#             .:      -0.33
# word: real, score: [0 0 0 1 0]
#          real:      -1.17
# word: search, score: [0 0 1 0 0]
#        search:       1.35
# word: out, score: [0 0 1 0 0]
#           out:       0.05
# word: it, score: [0 0 1 0 0]
#            it:      -0.15
# word: ., score: [0 0 1 0 0]
#             .:      -0.29
# word: entertain, score: [0 0 0 0 1]
#     entertain:       4.62
# word: !, score: [0 0 1 0 0]
#             !:       2.01
# word: tailored, score: [0 0 1 0 0]
#      tailored:      -0.11
# word: to, score: [0 0 1 0 0]
#            to:      -0.12
# word: insomnia, score: [0 1 0 0 0]
#      insomnia:       1.74
# word: is, score: [0 0 1 0 0]
#            is:      -0.33
# word: ., score: [0 0 1 0 0]
#             .:      -0.43
# word: involving, score: [0 0 1 0 0]
#     involving:      -1.42
# word: haunting, score: [0 0 1 0 0]
#      haunting:       1.45
# word: ., score: [0 0 1 0 0]
#             .:       0.18
# word: it, score: [0 0 1 0 0]
#            it:       0.09
# word: 's, score: [0 0 1 0 0]
#            's:       0.06
# word: loved, score: [0 0 0 0 1]
#         loved:       4.39
# word: !, score: [0 0 1 0 0]
#             !:       1.81
# word: it, score: [0 0 1 0 0]
#            it:       0.63
# word: i, score: [0 0 1 0 0]
#             i:       0.61
# word: astonishing, score: [0 0 0 0 1]
#   astonishing:       4.09
# word: ., score: [0 0 1 0 0]
#             .:       0.76
# word: it, score: [0 0 1 0 0]
#            it:       0.00
# word: 's, score: [0 0 1 0 0]
#            's:      -0.19
# word: why, score: [0 0 1 0 0]
#           why:       1.04
# word: wonder, score: [0 0 0 1 0]
#        wonder:       0.33
# word: i, score: [0 0 1 0 0]
#             i:      -0.22
# word: ., score: [0 0 1 0 0]
#             .:      -0.47
# word: high, score: [0 0 0 1 0]
#          high:       2.07
# word: ., score: [0 0 1 0 0]
#             .:       0.13
# word: melodrama, score: [0 0 1 0 0]
#     melodrama:      -0.13
# word: on, score: [0 0 1 0 0]
#            on:      -0.40
# word: now, score: [0 0 1 0 0]
#           now:       0.33
# word: it, score: [0 0 1 0 0]
#            it:       0.24
# word: ., score: [0 0 1 0 0]
#             .:       0.17
# word: is, score: [0 0 1 0 0]
#            is:       0.11
# word: ?, score: [0 0 1 0 0]
#             ?:       1.61
# word: progress, score: [0 0 1 0 0]
#      progress:       0.18
# word: is, score: [0 0 1 0 0]
#            is:      -0.10
# word: this, score: [0 0 1 0 0]
#          this:      -0.27
# word: but, score: [0 0 1 0 0]
#           but:       0.37
# word: biopic, score: [0 0 1 0 0]
#        biopic:       0.18
# word: effective, score: [0 0 0 1 0]
#     effective:       0.05
# word: too-tepid, score: [0 0 1 0 0]
#     too-tepid:      -0.14
# word: bad, score: [1 0 0 0 0]
#           bad:       4.45
# word: bears, score: [0 0 1 0 0]
#         bears:       0.09
# word: ., score: [0 0 1 0 0]
#             .:       0.01
# word: is, score: [0 0 1 0 0]
#            is:      -0.33
# word: imaginative, score: [0 0 0 0 1]
#   imaginative:       2.56
# word: an, score: [0 0 1 0 0]
#            an:       0.41
# word: ., score: [0 0 1 0 0]
#             .:       0.25
# word: comedy\/thriller, score: [0 0 1 0 0]
# comedy\/thriller:       0.02
# word: hate, score: [1 0 0 0 0]
#          hate:       4.12
# word: i, score: [0 0 1 0 0]
#             i:       0.10
# word: movie, score: [0 0 1 0 0]
#         movie:       0.07
# word: this, score: [0 0 1 0 0]
#          this:      -0.86
# word: or, score: [0 0 1 0 0]
#            or:       0.41
# word: profit, score: [0 0 1 0 0]
#        profit:       0.22
# word: a, score: [0 0 1 0 0]
#             a:      -0.15
# word: ., score: [0 0 1 0 0]
#             .:      -0.21
# word: painful, score: [0 1 0 0 0]
#       painful:       2.96
# word: it, score: [0 0 1 0 0]
#            it:      -0.05
# word: 's, score: [0 0 1 0 0]
#            's:      -0.07
# word: ., score: [0 0 1 0 0]
#             .:      -0.11
# word: does, score: [0 0 1 0 0]
#          does:       0.42
# word: this, score: [0 0 1 0 0]
#          this:       0.17
# word: one, score: [0 0 1 0 0]
#           one:       0.01
# word: ., score: [0 0 1 0 0]
#             .:      -0.05
# word: ?, score: [0 0 1 0 0]
#             ?:       0.65
# word: what, score: [0 0 1 0 0]
#          what:       0.38
# word: next, score: [0 0 1 0 0]
#          next:       0.23
# word: 's, score: [0 0 1 0 0]
#            's:       0.13
# word: away, score: [0 0 1 0 0]
#          away:       2.97
# word: ., score: [0 0 1 0 0]
#             .:       0.95
# word: pound, score: [0 0 1 0 0]
#         pound:       0.26
# word: just, score: [0 0 1 0 0]
#          just:       0.07
# word: documentary, score: [0 0 1 0 0]
#   documentary:       2.18
# word: boisterous, score: [0 0 1 0 0]
#    boisterous:       1.44
# word: daft, score: [0 1 0 0 0]
#          daft:       1.04
# word: ., score: [0 0 1 0 0]
#             .:       0.74
# word: and, score: [0 0 1 0 0]
#           and:       0.63
# word: mess, score: [0 1 0 0 0]
#          mess:       5.07
# word: just, score: [0 0 1 0 0]
#          just:       0.39
# word: ., score: [0 0 1 0 0]
#             .:       0.05
# word: a, score: [0 0 1 0 0]
#             a:      -0.01
# word: bloody, score: [0 1 0 0 0]
#        bloody:      -0.79
# word: nothing, score: [0 1 0 0 0]
#       nothing:       1.83
# word: about, score: [0 0 1 0 0]
#         about:       0.14
# word: ., score: [0 0 1 0 0]
#             .:      -0.16
# word: it, score: [0 0 1 0 0]
#            it:      -0.17
# word: fits, score: [0 0 0 1 0]
#          fits:      -1.26
# word: much, score: [0 0 1 0 0]
#          much:       0.23
# word: all, score: [0 0 1 0 0]
#           all:       0.17
# word: monkeyfun, score: [0 0 1 0 0]
#     monkeyfun:       0.16
# word: ., score: [0 0 1 0 0]
#             .:       0.11
# word: for, score: [0 0 1 0 0]
#           for:      -0.11
# word: vivid, score: [0 0 0 1 0]
#         vivid:       2.64
# word: portrait, score: [0 0 0 1 0]
#      portrait:       1.92
# word: cinematic, score: [0 0 0 1 0]
#     cinematic:       1.81
# word: ., score: [0 0 1 0 0]
#             .:       0.52
# word: a, score: [0 0 1 0 0]
#             a:       0.26
# word: did, score: [0 0 1 0 0]
#           did:       0.19
# word: ., score: [0 0 1 0 0]
#             .:       0.17
# word: so, score: [0 0 1 0 0]
#            so:       0.12
# word: just, score: [0 0 1 0 0]
#          just:       0.02
# word: i, score: [0 0 1 0 0]
#             i:      -0.20
# word: not, score: [0 1 0 0 0]
#           not:       1.74
# word: topkapi, score: [0 0 1 0 0]
#       topkapi:      -0.09
# word: is, score: [0 0 1 0 0]
#            is:      -0.15
# word: ., score: [0 0 1 0 0]
#             .:      -0.17
# word: this, score: [0 0 1 0 0]
#          this:      -0.27
# word: worth, score: [0 0 0 1 0]
#         worth:       3.36
# word: well, score: [0 0 0 1 0]
#          well:       1.71
# word: ., score: [0 0 1 0 0]
#             .:       0.59
# word: time, score: [0 0 1 0 0]
#          time:       0.42
# word: the, score: [0 0 1 0 0]
#           the:       0.10
# word: n't, score: [0 1 0 0 0]
#           n't:       1.66
# word: boring, score: [1 0 0 0 0]
#        boring:       0.45
# word: did, score: [0 0 1 0 0]
#           did:       0.03
# word: we, score: [0 0 1 0 0]
#            we:      -0.00
# word: ., score: [0 0 1 0 0]
#             .:      -0.11
# word: for, score: [0 0 1 0 0]
#           for:       0.37
# word: caine, score: [0 0 1 0 0]
#         caine:       0.29
# word: only, score: [0 0 1 0 0]
#          only:       0.18
# word: ., score: [0 0 1 0 0]
#             .:       0.10
# word: lovers, score: [0 0 1 0 0]
#        lovers:       0.09
# word: sudsy, score: [0 1 0 0 0]
#         sudsy:       1.93
# word: cautionary, score: [0 0 1 0 0]
#    cautionary:       0.05
# word: a, score: [0 0 1 0 0]
#             a:      -0.12
# word: ., score: [0 0 1 0 0]
#             .:      -0.29
# word: tale, score: [0 0 1 0 0]
#          tale:      -0.80
# word: ingenious, score: [0 0 0 0 1]
#     ingenious:       3.32
# word: entertainment, score: [0 0 0 1 0]
# entertainment:       2.63
# word: resourceful, score: [0 0 0 1 0]
#   resourceful:       1.56
# word: ., score: [0 0 1 0 0]
#             .:       0.69
# word: and, score: [0 0 1 0 0]
#           and:       0.59
# word: pleasant, score: [0 0 0 0 1]
#      pleasant:       3.56
# word: romantic, score: [0 0 1 0 0]
#      romantic:       1.31
# word: comedy, score: [0 0 1 0 0]
#        comedy:       1.30
# word: ., score: [0 0 1 0 0]
#             .:       0.51
# word: a, score: [0 0 1 0 0]
#             a:       0.28
# word: !, score: [0 0 1 0 0]
#             !:       0.94
# word: super, score: [0 0 0 1 0]
#         super:       0.80
# word: 's, score: [0 0 1 0 0]
#            's:      -0.05
# word: he, score: [0 0 1 0 0]
#            he:      -0.13
# word: spy, score: [0 0 1 0 0]
#           spy:      -0.21
# word: bourne, score: [0 0 1 0 0]
#        bourne:       0.68
# word: bourne, score: [0 0 1 0 0]
#        bourne:       0.37
# word: ., score: [0 0 1 0 0]
#             .:       0.15
# word: ,, score: [0 0 1 0 0]
#             ,:       0.12
# word: jason, score: [0 0 1 0 0]
#         jason:      -0.18
# word: brilliant, score: [0 0 0 0 1]
#     brilliant:       5.37
# word: documentary, score: [0 0 1 0 0]
#   documentary:       1.96
# word: ., score: [0 0 1 0 0]
#             .:       0.81
# word: and, score: [0 0 1 0 0]
#           and:       0.70
# word: disturbing, score: [0 1 0 0 0]
#    disturbing:      -1.60
# word: lucas, score: [0 0 1 0 0]
#         lucas:       0.38
# word: ,, score: [0 0 1 0 0]
#             ,:       0.15
# word: take, score: [0 0 1 0 0]
#          take:       0.15
# word: notes, score: [0 0 1 0 0]
#         notes:       0.13
# word: ., score: [0 0 1 0 0]
#             .:       0.10
# word: provocative, score: [0 0 0 1 0]
#   provocative:       4.19
# word: energetic, score: [0 0 0 1 0]
#     energetic:       2.48
# word: boldly, score: [0 0 1 0 0]
#        boldly:       0.95
# word: and, score: [0 0 1 0 0]
#           and:       0.49
# word: ., score: [0 0 1 0 0]
#             .:       0.48
# word: n't, score: [0 1 0 0 0]
#           n't:       1.45
# word: ?, score: [0 0 1 0 0]
#             ?:       1.15
# word: it, score: [0 0 1 0 0]
#            it:      -0.00
# word: is, score: [0 0 1 0 0]
#            is:      -0.05
# word: great, score: [0 0 0 0 1]
#         great:      -0.85
# word: wonderful, score: [0 0 0 0 1]
#     wonderful:       4.85
# word: comedy, score: [0 0 1 0 0]
#        comedy:       2.71
# word: ., score: [0 0 1 0 0]
#             .:       0.72
# word: a, score: [0 0 1 0 0]
#             a:       0.35
# word: character-based, score: [0 0 1 0 0]
# character-based:      -0.42
# word: affecting, score: [0 0 1 0 0]
#     affecting:       2.23
# word: remarkably, score: [0 0 0 1 0]
#    remarkably:       1.93
# word: accessible, score: [0 0 0 1 0]
#    accessible:       1.61
# word: and, score: [0 0 1 0 0]
#           and:       0.65
# word: ., score: [0 0 1 0 0]
#             .:       0.51
# word: trifle, score: [0 0 1 0 0]
#        trifle:       1.27
# word: 's, score: [0 0 1 0 0]
#            's:       0.01
# word: a, score: [0 0 1 0 0]
#             a:      -0.16
# word: it, score: [0 0 1 0 0]
#            it:      -0.18
# word: ., score: [0 0 1 0 0]
#             .:      -0.30
# word: appealing, score: [0 0 0 1 0]
#     appealing:       5.23
# word: and, score: [0 0 1 0 0]
#           and:       0.88
# word: ., score: [0 0 1 0 0]
#             .:       0.54
# word: both, score: [0 0 1 0 0]
#          both:       0.16
# word: awful, score: [1 0 0 0 0]
#         awful:      -2.10
# word: chiller, score: [0 0 0 1 0]
#       chiller:       3.02
# word: solidly, score: [0 0 0 1 0]
#       solidly:       1.65
# word: ., score: [0 0 1 0 0]
#             .:       0.64
# word: seaworthy, score: [0 0 1 0 0]
#     seaworthy:       0.43
# word: a, score: [0 0 1 0 0]
#             a:       0.17
# word: steal, score: [0 0 0 1 0]
#         steal:       1.32
# word: actors, score: [0 0 1 0 0]
#        actors:       0.22
# word: ., score: [0 0 1 0 0]
#             .:       0.19
# word: scenes, score: [0 0 1 0 0]
#        scenes:       0.14
# word: some, score: [0 0 1 0 0]
#          some:       0.09
# word: funny, score: [0 0 0 1 0]
#         funny:       4.42
# word: very, score: [0 0 1 0 0]
#          very:       1.03
# word: movie, score: [0 0 1 0 0]
#         movie:       0.98
# word: ., score: [0 0 1 0 0]
#             .:       0.86
# word: a, score: [0 0 1 0 0]
#             a:       0.22
# word: thing, score: [0 0 1 0 0]
#         thing:       0.93
# word: or, score: [0 0 1 0 0]
#            or:       0.22
# word: some, score: [0 0 1 0 0]
#          some:       0.03
# word: ., score: [0 0 1 0 0]
#             .:      -0.31
# word: damn, score: [0 1 0 0 0]
#          damn:      -0.75
# word: excellent, score: [0 0 0 0 1]
#     excellent:       5.33
# word: acting, score: [0 0 1 0 0]
#        acting:       0.97
# word: and, score: [0 0 1 0 0]
#           and:       0.95
# word: direction, score: [0 0 1 0 0]
#     direction:       0.89
# word: ., score: [0 0 1 0 0]
#             .:       0.69
# word: largely, score: [0 0 1 0 0]
#       largely:       0.28
# word: artifact, score: [0 0 1 0 0]
#      artifact:       0.22
# word: for-fans, score: [0 0 1 0 0]
#      for-fans:       0.02
# word: a, score: [0 0 1 0 0]
#             a:      -0.13
# word: ., score: [0 0 1 0 0]
#             .:      -0.32
# word: bad, score: [1 0 0 0 0]
#           bad:       3.14
# word: sign, score: [0 1 0 0 0]
#          sign:       1.65
# word: ., score: [0 0 1 0 0]
#             .:       0.22
# word: a, score: [0 0 1 0 0]
#             a:       0.06
# word: very, score: [0 0 1 0 0]
#          very:      -0.05
# word: dreadful, score: [1 0 0 0 0]
#      dreadful:       5.51
# word: a, score: [0 0 1 0 0]
#             a:       0.16
# word: movie, score: [0 0 1 0 0]
#         movie:      -0.00
# word: ., score: [0 0 1 0 0]
#             .:      -0.35
# word: live-action, score: [0 0 1 0 0]
#   live-action:      -0.73
# word: n't, score: [0 1 0 0 0]
#           n't:       2.12
# word: but, score: [0 0 1 0 0]
#           but:       0.36
# word: was, score: [0 0 1 0 0]
#           was:       0.02
# word: ., score: [0 0 1 0 0]
#             .:      -0.13
# word: i, score: [0 0 1 0 0]
#             i:      -0.37
# word: also, score: [0 0 1 0 0]
#          also:       0.62
# word: stupider, score: [0 0 1 0 0]
#      stupider:       0.53
# word: ., score: [0 0 1 0 0]
#             .:       0.20
# word: 's, score: [0 0 1 0 0]
#            's:       0.02
# word: it, score: [0 0 1 0 0]
#            it:       0.01
# word: in, score: [0 0 1 0 0]
#            in:       0.69
# word: yes, score: [0 0 1 0 0]
#           yes:       0.53
# word: a, score: [0 0 1 0 0]
#             a:       0.19
# word: --, score: [0 0 1 0 0]
#            --:       0.18
# word: word, score: [0 0 1 0 0]
#          word:       0.15
# word: ., score: [0 0 1 0 0]
#             .:       0.08
# word: hilarious, score: [0 0 0 0 1]
#     hilarious:       6.54
# word: comedy, score: [0 0 1 0 0]
#        comedy:       2.05
# word: ., score: [0 0 1 0 0]
#             .:       0.42
# word: ,, score: [0 0 1 0 0]
#             ,:       0.03
# word: brit, score: [0 0 1 0 0]
#          brit:      -0.72
# word: acidic, score: [0 0 1 0 0]
#        acidic:      -1.78
# word: waste, score: [1 0 0 0 0]
#         waste:       2.66
# word: money, score: [0 0 1 0 0]
#         money:       1.20
# word: your, score: [0 0 1 0 0]
#          your:       0.12
# word: do, score: [0 0 1 0 0]
#            do:       0.11
# word: ., score: [0 0 1 0 0]
#             .:      -0.08
# word: n't, score: [0 1 0 0 0]
#           n't:      -0.42
# word: us, score: [0 0 0 1 0]
#            us:       1.04
# word: laughing, score: [0 0 0 0 1]
#      laughing:       0.98
# word: ., score: [0 0 1 0 0]
#             .:       0.12
# word: it, score: [0 0 1 0 0]
#            it:       0.07
# word: at, score: [0 0 1 0 0]
#            at:      -0.01
# word: 's, score: [0 0 1 0 0]
#            's:      -0.02
# word: shines, score: [0 0 0 0 1]
#        shines:       4.08
# word: unfaithful, score: [0 0 1 0 0]
#    unfaithful:       1.10
# word: lane, score: [0 0 1 0 0]
#          lane:       1.01
# word: ., score: [0 0 1 0 0]
#             .:       0.72
# word: in, score: [0 0 1 0 0]
#            in:       0.05
# word: diane, score: [0 0 1 0 0]
#         diane:       0.01
# word: good, score: [0 0 0 1 0]
#          good:       2.49
# word: legend, score: [0 0 0 1 0]
#        legend:       1.15
# word: stuff, score: [0 0 1 0 0]
#         stuff:       0.63
# word: ., score: [0 0 1 0 0]
#             .:       0.20
# word: urban, score: [0 0 1 0 0]
#         urban:      -0.02
# word: ol', score: [0 0 0 1 0]
#           ol':      -0.36
# word: closer, score: [0 0 1 0 0]
#        closer:       1.03
# word: slowtime, score: [0 0 1 0 0]
#      slowtime:       0.22
# word: ., score: [0 0 1 0 0]
#             .:       0.20
# word: is, score: [0 0 1 0 0]
#            is:       0.17
# word: to, score: [0 0 1 0 0]
#            to:       0.07
# word: showtime, score: [0 0 1 0 0]
#      showtime:      -0.36
# word: dicey, score: [0 1 0 0 0]
#         dicey:       0.49
# word: pretty, score: [0 0 1 0 0]
#        pretty:       0.10
# word: ., score: [0 0 1 0 0]
#             .:       0.07
# word: is, score: [0 0 1 0 0]
#            is:       0.06
# word: this, score: [0 0 1 0 0]
#          this:       0.05
# word: material, score: [0 0 1 0 0]
#      material:       0.00
# word: sometimes, score: [0 0 1 0 0]
#     sometimes:       0.60
# word: enough, score: [0 0 1 0 0]
#        enough:       0.30
# word: ,, score: [0 0 1 0 0]
#             ,:       0.18
# word: ., score: [0 0 1 0 0]
#             .:       0.12
# word: 's, score: [0 0 1 0 0]
#            's:       0.10
# word: that, score: [0 0 1 0 0]
#          that:       0.07
# word: awkward, score: [0 1 0 0 0]
#       awkward:       1.81
# word: indigestible, score: [0 0 1 0 0]
#  indigestible:       0.56
# word: an, score: [0 0 1 0 0]
#            an:      -0.04
# word: and, score: [0 0 1 0 0]
#           and:      -0.13
# word: movie, score: [0 0 1 0 0]
#         movie:      -0.28
# word: ., score: [0 0 1 0 0]
#             .:      -0.34
# word: neither, score: [0 0 1 0 0]
#       neither:       2.29
# word: 's, score: [0 0 1 0 0]
#            's:       0.06
# word: ,, score: [0 0 1 0 0]
#             ,:      -0.06
# word: alas, score: [0 0 1 0 0]
#          alas:      -0.10
# word: it, score: [0 0 1 0 0]
#            it:      -0.11
# word: ., score: [0 0 1 0 0]
#             .:      -0.16
# word: ?, score: [0 0 1 0 0]
#             ?:       1.73
# word: d.j., score: [0 0 1 0 0]
#          d.j.:       0.12
# word: as, score: [0 0 1 0 0]
#            as:       0.07
# word: qualls, score: [0 0 1 0 0]
#        qualls:      -0.11
# word: jones, score: [0 0 1 0 0]
#         jones:      -0.36
# word: indiana, score: [0 0 1 0 0]
#       indiana:      -0.58
# word: tremendous, score: [0 0 0 0 1]
#    tremendous:       3.31
# word: performance, score: [0 0 0 0 1]
#   performance:       3.11
# word: gives, score: [0 0 1 0 0]
#         gives:       0.75
# word: ., score: [0 0 1 0 0]
#             .:       0.65
# word: kinnear, score: [0 0 1 0 0]
#       kinnear:       0.32
# word: a, score: [0 0 1 0 0]
#             a:       0.28
# word: enjoy, score: [0 0 0 0 1]
#         enjoy:       3.55
# word: see, score: [0 0 1 0 0]
#           see:       0.93
# word: ., score: [0 0 1 0 0]
#             .:       0.60
# word: and, score: [0 0 1 0 0]
#           and:       0.54
# word: it, score: [0 0 1 0 0]
#            it:       0.26
# word: go, score: [0 0 1 0 0]
#            go:      -0.29
# word: ?, score: [0 0 1 0 0]
#             ?:       1.34
# word: nash, score: [0 0 1 0 0]
#          nash:       0.31
# word: happened, score: [0 0 1 0 0]
#      happened:       0.05
# word: what, score: [0 0 1 0 0]
#          what:      -0.00
# word: pluto, score: [0 0 1 0 0]
#         pluto:      -0.08
# word: with, score: [0 0 1 0 0]
#          with:      -0.15
# word: genuine, score: [0 0 0 0 1]
#       genuine:       5.61
# word: always, score: [0 0 1 0 0]
#        always:       0.79
# word: ., score: [0 0 1 0 0]
#             .:       0.73
# word: remains, score: [0 1 0 0 0]
#       remains:       0.37
# word: movingly, score: [0 0 1 0 0]
#      movingly:       0.23
# word: ..., score: [0 0 1 0 0]
#           ...:       0.12
# word: for, score: [0 0 1 0 0]
#           for:       0.10
# word: by, score: [0 0 1 0 0]
#            by:       0.08
# word: jackasses, score: [0 0 1 0 0]
#     jackasses:       0.04
# word: jackasses, score: [0 0 1 0 0]
#     jackasses:       0.02
# word: made, score: [0 0 1 0 0]
#          made:      -0.06
# word: ., score: [0 0 1 0 0]
#             .:      -0.32
# word: emptiness, score: [0 1 0 0 0]
#     emptiness:       1.62
# word: exercise, score: [0 0 1 0 0]
#      exercise:       0.61
# word: in, score: [0 0 1 0 0]
#            in:      -0.03
# word: a, score: [0 0 1 0 0]
#             a:      -0.14
# word: ., score: [0 0 1 0 0]
#             .:      -0.36
# word: bravura, score: [0 0 0 1 0]
#       bravura:      -2.68
# word: good, score: [0 0 0 1 0]
#          good:       1.98
# word: ., score: [0 0 1 0 0]
#             .:       0.17
# word: ,, score: [0 0 1 0 0]
#             ,:       0.06
# word: bothersome, score: [0 0 1 0 0]
#    bothersome:       0.03
# word: first, score: [0 0 1 0 0]
#         first:       0.01
# word: then, score: [0 0 1 0 0]
#          then:      -0.21
# word: predictable, score: [0 1 0 0 0]
#   predictable:       2.03
# word: long-winded, score: [0 1 0 0 0]
#   long-winded:       1.61
# word: a, score: [0 0 1 0 0]
#             a:       0.02
# word: ,, score: [0 0 1 0 0]
#             ,:      -0.11
# word: ., score: [0 0 1 0 0]
#             .:      -0.21
# word: scenario, score: [0 0 1 0 0]
#      scenario:      -0.30
# word: fun, score: [0 0 0 0 1]
#           fun:       3.01
# word: fascinating, score: [0 0 0 0 1]
#   fascinating:       2.80
# word: film, score: [0 0 1 0 0]
#          film:       1.36
# word: ., score: [0 0 1 0 0]
#             .:       0.56
# word: and, score: [0 0 1 0 0]
#           and:       0.42
# word: a, score: [0 0 1 0 0]
#             a:       0.24
# word: wan, score: [0 1 0 0 0]
#           wan:       0.91
# word: else, score: [0 0 1 0 0]
#          else:       0.31
# word: almost, score: [0 0 1 0 0]
#        almost:       0.03
# word: everything, score: [0 0 1 0 0]
#    everything:       0.01
# word: is, score: [0 0 1 0 0]
#            is:      -0.09
# word: ., score: [0 0 1 0 0]
#             .:      -0.19
# word: exhausting, score: [0 1 0 0 0]
#    exhausting:       4.35
# word: but, score: [0 0 1 0 0]
#           but:       0.05
# word: ., score: [0 0 1 0 0]
#             .:      -0.34
# word: cinema, score: [0 0 1 0 0]
#        cinema:      -1.02
# word: love, score: [0 0 0 0 1]
#          love:      -1.16
# word: enduring, score: [0 0 0 1 0]
#      enduring:      -2.28
# word: authentic, score: [0 0 0 1 0]
#     authentic:       2.52
# word: refreshingly, score: [0 0 0 1 0]
#  refreshingly:       2.32
# word: coming-of-age, score: [0 0 1 0 0]
# coming-of-age:       1.27
# word: tale, score: [0 0 1 0 0]
#          tale:       0.80
# word: ., score: [0 0 1 0 0]
#             .:       0.43
# word: a, score: [0 0 1 0 0]
#             a:       0.26
# word: slight, score: [0 0 1 0 0]
#        slight:       0.42
# word: but, score: [0 0 1 0 0]
#           but:       0.36
# word: professional, score: [0 0 0 1 0]
#  professional:       0.20
# word: ., score: [0 0 1 0 0]
#             .:       0.07
# word: finally, score: [0 0 1 0 0]
#       finally:       0.05
# word: faultlessly, score: [0 0 1 0 0]
#   faultlessly:       0.04
# word: lame, score: [1 0 0 0 0]
#          lame:       3.68
# word: haphazard, score: [1 0 0 0 0]
#     haphazard:       2.17
# word: teen, score: [0 0 1 0 0]
#          teen:       0.75
# word: ., score: [0 0 1 0 0]
#             .:      -0.02
# word: ,, score: [0 0 1 0 0]
#             ,:      -0.18
# word: comedy, score: [0 0 1 0 0]
#        comedy:      -0.61
# word: ?, score: [0 0 1 0 0]
#             ?:       1.69
# word: point, score: [0 0 1 0 0]
#         point:       0.15
# word: what, score: [0 0 1 0 0]
#          what:       0.05
# word: the, score: [0 0 1 0 0]
#           the:      -0.01
# word: is, score: [0 0 1 0 0]
#            is:      -0.17
# word: so, score: [0 0 1 0 0]
#            so:      -0.49
# word: dull, score: [1 0 0 0 0]
#          dull:       4.30
# word: incredibly, score: [0 0 0 1 0]
#    incredibly:       0.31
# word: just, score: [0 0 1 0 0]
#          just:       0.21
# word: 's, score: [0 0 1 0 0]
#            's:       0.08
# word: it, score: [0 0 1 0 0]
#            it:       0.05
# word: ., score: [0 0 1 0 0]
#             .:       0.02
# word: ?, score: [0 0 1 0 0]
#             ?:       1.15
# word: q, score: [0 0 1 0 0]
#             q:       0.05
# word: happens, score: [0 0 1 0 0]
#       happens:       0.04
# word: what, score: [0 0 1 0 0]
#          what:      -0.00
# word: to, score: [0 0 1 0 0]
#            to:      -0.03
# word: john, score: [0 0 1 0 0]
#          john:      -0.07
# word: ending, score: [0 0 1 0 0]
#        ending:       0.12
# word: the, score: [0 0 1 0 0]
#           the:       0.01
# word: cop-out, score: [0 0 1 0 0]
#       cop-out:      -0.20
# word: a, score: [0 0 1 0 0]
#             a:      -0.29
# word: is, score: [0 0 1 0 0]
#            is:      -0.33
# word: ., score: [0 0 1 0 0]
#             .:      -0.50
# word: maudlin, score: [0 0 1 0 0]
#       maudlin:       0.72
# word: melodramatic, score: [0 0 1 0 0]
#  melodramatic:       0.32
# word: expected, score: [0 1 0 0 0]
#      expected:       0.16
# word: we, score: [0 0 1 0 0]
#            we:      -0.10
# word: and, score: [0 0 1 0 0]
#           and:      -0.23
# word: ., score: [0 0 1 0 0]
#             .:      -0.23
# word: tired, score: [0 1 0 0 0]
#         tired:       2.23
# word: just, score: [0 0 1 0 0]
#          just:       0.04
# word: 's, score: [0 0 1 0 0]
#            's:       0.04
# word: now, score: [0 0 1 0 0]
#           now:       0.03
# word: it, score: [0 0 1 0 0]
#            it:      -0.08
# word: ., score: [0 0 1 0 0]
#             .:      -0.15
# word: escapism, score: [0 0 1 0 0]
#      escapism:       0.34
# word: purest, score: [0 0 1 0 0]
#        purest:       0.13
# word: form, score: [0 0 1 0 0]
#          form:       0.11
# word: ., score: [0 0 1 0 0]
#             .:       0.09
# word: in, score: [0 0 1 0 0]
#            in:       0.09
# word: its, score: [0 0 1 0 0]
#           its:       0.01
# word: poem, score: [0 0 1 0 0]
#          poem:       1.59
# word: ., score: [0 0 1 0 0]
#             .:       0.24
# word: like, score: [0 0 1 0 0]
#          like:       0.20
# word: a, score: [0 0 1 0 0]
#             a:       0.15
# word: it, score: [0 0 1 0 0]
#            it:       0.10
# word: 's, score: [0 0 1 0 0]
#            's:       0.00
# word: sour, score: [0 1 0 0 0]
#          sour:       2.77
# word: nasty, score: [1 0 0 0 0]
#         nasty:       2.15
# word: a, score: [0 0 1 0 0]
#             a:       0.14
# word: ,, score: [0 0 1 0 0]
#             ,:      -0.12
# word: ., score: [0 0 1 0 0]
#             .:      -0.19
# word: offering, score: [0 0 1 0 0]
#      offering:      -0.62
# word: love, score: [0 0 0 0 1]
#          love:       3.64
# word: potent, score: [0 0 0 1 0]
#        potent:       2.05
# word: ., score: [0 0 1 0 0]
#             .:       0.71
# word: allegorical, score: [0 0 1 0 0]
#   allegorical:       0.37
# word: a, score: [0 0 1 0 0]
#             a:       0.26
# word: story, score: [0 0 1 0 0]
#         story:      -0.09
# word: lackluster, score: [0 1 0 0 0]
#    lackluster:       4.07
# word: ultimately, score: [0 0 1 0 0]
#    ultimately:       0.30
# word: movie, score: [0 0 1 0 0]
#         movie:       0.20
# word: much-anticipated, score: [0 0 1 0 0]
# much-anticipated:      -0.03
# word: and, score: [0 0 1 0 0]
#           and:      -0.21
# word: ., score: [0 0 1 0 0]
#             .:      -0.23
# word: waste, score: [1 0 0 0 0]
#         waste:       6.39
# word: of, score: [0 0 1 0 0]
#            of:       0.07
# word: a, score: [0 0 1 0 0]
#             a:       0.02
# word: ., score: [0 0 1 0 0]
#             .:      -0.32
# word: performances, score: [0 0 1 0 0]
#  performances:      -2.13
# word: good, score: [0 0 0 1 0]
#          good:      -2.57
# word: wonderful, score: [0 0 0 0 1]
#     wonderful:       5.42
# word: invincible, score: [0 0 0 1 0]
#    invincible:       1.18
# word: movie, score: [0 0 1 0 0]
#         movie:       1.00
# word: ., score: [0 0 1 0 0]
#             .:       0.90
# word: a, score: [0 0 1 0 0]
#             a:       0.42
# word: is, score: [0 0 1 0 0]
#            is:       0.39
# word: compelling, score: [0 0 0 1 0]
#    compelling:       2.25
# word: portrait, score: [0 0 0 1 0]
#      portrait:       1.03
# word: a, score: [0 0 1 0 0]
#             a:       0.15
# word: moral, score: [0 0 1 0 0]
#         moral:       0.11
# word: of, score: [0 0 1 0 0]
#            of:       0.03
# word: emptiness, score: [0 1 0 0 0]
#     emptiness:      -0.69
# word: funny, score: [0 0 0 1 0]
#         funny:       2.75
# word: wildly, score: [0 0 1 0 0]
#        wildly:       0.78
# word: ., score: [0 0 1 0 0]
#             .:       0.18
# word: a, score: [0 0 1 0 0]
#             a:       0.10
# word: caper, score: [0 0 1 0 0]
#         caper:      -0.25
# word: prison, score: [0 0 1 0 0]
#        prison:      -0.47
# word: south-of-the-border, score: [0 1 0 0 0]
# south-of-the-border:       0.35
# word: place, score: [0 0 1 0 0]
#         place:       0.07
# word: like, score: [0 0 1 0 0]
#          like:       0.02
# word: a, score: [0 0 1 0 0]
#             a:      -0.18
# word: melrose, score: [0 0 1 0 0]
#       melrose:      -0.45
# word: ., score: [0 0 1 0 0]
#             .:      -0.55
# word: lacks, score: [0 1 0 0 0]
#         lacks:       2.62
# word: central, score: [0 0 1 0 0]
#       central:       0.11
# word: story, score: [0 0 1 0 0]
#         story:       0.05
# word: the, score: [0 0 1 0 0]
#           the:      -0.02
# word: ., score: [0 0 1 0 0]
#             .:      -0.19
# word: punch, score: [0 0 1 0 0]
#         punch:      -0.56
# word: not, score: [0 1 0 0 0]
#           not:       2.95
# word: but, score: [0 0 1 0 0]
#           but:       0.12
# word: frenetic, score: [0 0 1 0 0]
#      frenetic:      -0.06
# word: ., score: [0 0 1 0 0]
#             .:      -0.20
# word: really, score: [0 0 1 0 0]
#        really:      -0.21
# word: funny, score: [0 0 0 1 0]
#         funny:      -1.73
# word: another, score: [0 0 1 0 0]
#       another:       0.73
# word: groan-inducing, score: [0 0 1 0 0]
# groan-inducing:       0.54
# word: begets, score: [0 0 1 0 0]
#        begets:       0.24
# word: one, score: [0 0 1 0 0]
#           one:       0.11
# word: familiarity, score: [0 0 1 0 0]
#   familiarity:       0.03
# word: ., score: [0 0 1 0 0]
#             .:      -0.53
# word: ?, score: [0 0 1 0 0]
#             ?:       3.54
# word: total, score: [0 0 1 0 0]
#         total:       0.93
# word: is, score: [0 0 1 0 0]
#            is:      -0.13
# word: it, score: [0 0 1 0 0]
#            it:      -0.13
# word: a, score: [0 0 1 0 0]
#             a:      -0.14
# word: success, score: [0 0 0 1 0]
#       success:      -4.71
# word: entertaining, score: [0 0 0 0 1]
#  entertaining:       3.73
# word: provocative, score: [0 0 0 1 0]
#   provocative:       2.16
# word: thoughtful, score: [0 0 0 0 1]
#    thoughtful:       2.06
# word: ., score: [0 0 1 0 0]
#             .:       0.46
# word: and, score: [0 0 1 0 0]
#           and:       0.43
# word: ,, score: [0 0 1 0 0]
#             ,:       0.13
# word: worth, score: [0 0 0 1 0]
#         worth:       2.44
# word: watch, score: [0 0 1 0 0]
#         watch:       0.46
# word: ., score: [0 0 1 0 0]
#             .:       0.12
# word: effort, score: [0 0 1 0 0]
#        effort:       0.03
# word: to, score: [0 0 1 0 0]
#            to:      -0.05
# word: the, score: [0 0 1 0 0]
#           the:      -0.11
# word: thriller, score: [0 0 0 1 0]
#      thriller:       6.15
# word: unsatisfying, score: [1 0 0 0 0]
#  unsatisfying:       1.37
# word: ., score: [0 0 1 0 0]
#             .:       1.08
# word: creepy, score: [0 1 0 0 0]
#        creepy:       0.15
# word: but, score: [0 0 1 0 0]
#           but:      -0.33
# word: ultimately, score: [0 0 1 0 0]
#    ultimately:      -0.56
# word: ridiculous, score: [0 1 0 0 0]
#    ridiculous:       2.43
# word: noisy, score: [0 1 0 0 0]
#         noisy:       2.20
# word: divertingly, score: [0 0 1 0 0]
#   divertingly:      -0.05
# word: headbangingly, score: [0 0 1 0 0]
# headbangingly:      -0.06
# word: ., score: [0 0 1 0 0]
#             .:      -0.07
# word: ,, score: [0 0 1 0 0]
#             ,:      -0.09
# word: dull, score: [1 0 0 0 0]
#          dull:       4.66
# word: too, score: [0 1 0 0 0]
#           too:       1.13
# word: to, score: [0 0 1 0 0]
#            to:       0.12
# word: ..., score: [0 0 1 0 0]
#           ...:       0.10
# word: ., score: [0 0 1 0 0]
#             .:      -0.21
# word: enjoy, score: [0 0 0 0 1]
#         enjoy:      -2.96
# word: melanie, score: [0 0 1 0 0]
#       melanie:       0.21
# word: the, score: [0 0 1 0 0]
#           the:       0.04
# word: eventually, score: [0 0 1 0 0]
#    eventually:      -0.25
# word: slugs, score: [0 0 1 0 0]
#         slugs:      -0.36
# word: yankee, score: [0 0 1 0 0]
#        yankee:      -0.36
# word: ., score: [0 0 1 0 0]
#             .:      -0.46
# word: stupid, score: [1 0 0 0 0]
#        stupid:       4.18
# word: nrelentingly, score: [0 0 1 0 0]
#  nrelentingly:       0.14
# word: u, score: [0 0 1 0 0]
#             u:       0.08
# word: ., score: [0 0 1 0 0]
#             .:      -0.02
# word: -rrb-, score: [0 0 1 0 0]
#         -rrb-:      -0.28
# word: -lrb-, score: [0 0 1 0 0]
#         -lrb-:      -0.35
# word: forgettable, score: [1 0 0 0 0]
#   forgettable:       3.41
# word: ,, score: [0 0 1 0 0]
#             ,:      -0.13
# word: light, score: [0 0 1 0 0]
#         light:      -0.24
# word: and, score: [0 0 1 0 0]
#           and:      -0.28
# word: ., score: [0 0 1 0 0]
#             .:      -0.37
# word: cute, score: [0 0 0 1 0]
#          cute:      -3.02
# word: against, score: [0 0 1 0 0]
#       against:       0.77
# word: progress, score: [0 0 1 0 0]
#      progress:       0.26
# word: nature, score: [0 0 1 0 0]
#        nature:      -0.01
# word: it, score: [0 0 1 0 0]
#            it:      -0.16
# word: is, score: [0 0 1 0 0]
#            is:      -0.20
# word: ., score: [0 0 1 0 0]
#             .:      -0.29
# word: between, score: [0 0 1 0 0]
#       between:       0.56
# word: drama, score: [0 0 1 0 0]
#         drama:       0.38
# word: ?, score: [0 0 1 0 0]
#             ?:       0.33
# word: cube, score: [0 0 1 0 0]
#          cube:       0.20
# word: the, score: [0 0 1 0 0]
#           the:       0.17
# word: of, score: [0 0 1 0 0]
#            of:       0.03
# word: illuminating, score: [0 0 0 1 0]
#  illuminating:       2.62
# word: documentary, score: [0 0 1 0 0]
#   documentary:       0.30
# word: ., score: [0 0 1 0 0]
#             .:       0.06
# word: talky, score: [0 0 1 0 0]
#         talky:      -0.06
# word: if, score: [0 0 1 0 0]
#            if:      -0.44
# word: overly, score: [0 1 0 0 0]
#        overly:      -1.10
# word: ill-fitting, score: [0 1 0 0 0]
#   ill-fitting:       2.64
# word: tuxedo, score: [0 0 1 0 0]
#        tuxedo:       1.17
# word: this, score: [0 0 1 0 0]
#          this:       0.54
# word: strictly, score: [0 0 1 0 0]
#      strictly:      -0.13
# word: ., score: [0 0 1 0 0]
#             .:      -0.31
# word: off-the-rack, score: [0 0 1 0 0]
#  off-the-rack:      -0.49
# word: is, score: [0 0 1 0 0]
#            is:      -0.57
# word: hilarious, score: [0 0 0 0 1]
#     hilarious:       5.79
# word: ., score: [0 0 1 0 0]
#             .:       0.91
# word: thurman, score: [0 0 0 1 0]
#       thurman:       0.54
# word: and, score: [0 0 1 0 0]
#           and:       0.42
# word: lewis, score: [0 0 0 1 0]
#         lewis:       0.21
# word: throughout, score: [0 0 1 0 0]
#    throughout:       0.01
# word: are, score: [0 0 1 0 0]
#           are:      -0.01
# word: fine, score: [0 0 0 1 0]
#          fine:       2.91
# word: well, score: [0 0 0 1 0]
#          well:       2.84
# word: ., score: [0 0 1 0 0]
#             .:       0.59
# word: are, score: [0 0 1 0 0]
#           are:      -0.01
# word: voices, score: [0 0 1 0 0]
#        voices:      -0.04
# word: as, score: [0 0 1 0 0]
#            as:      -0.09
# word: the, score: [0 0 1 0 0]
#           the:      -0.13
# word: than, score: [0 0 1 0 0]
#          than:       0.39
# word: weaker, score: [0 0 1 0 0]
#        weaker:       0.29
# word: 's, score: [0 0 1 0 0]
#            's:       0.13
# word: ., score: [0 0 1 0 0]
#             .:      -0.39
# word: this, score: [0 0 1 0 0]
#          this:      -0.44
# word: most, score: [0 0 1 0 0]
#          most:      -0.49
# word: one, score: [0 0 1 0 0]
#           one:      -0.50
# word: work, score: [0 0 1 0 0]
#          work:       1.21
# word: this, score: [0 0 1 0 0]
#          this:       0.95
# word: lot, score: [0 0 1 0 0]
#           lot:       0.80
# word: ., score: [0 0 1 0 0]
#             .:       0.60
# word: a, score: [0 0 1 0 0]
#             a:       0.47
# word: i, score: [0 0 1 0 0]
#             i:       0.36
# word: admired, score: [0 0 1 0 0]
#       admired:      -0.79
# word: no, score: [0 1 0 0 0]
#            no:       3.23
# word: the, score: [0 0 1 0 0]
#           the:      -0.02
# word: movie, score: [0 0 1 0 0]
#         movie:      -0.14
# word: sense, score: [0 0 1 0 0]
#         sense:      -0.20
# word: ., score: [0 0 1 0 0]
#             .:      -0.40
# word: makes, score: [0 0 1 0 0]
#         makes:      -0.52
# word: absolutely, score: [0 0 0 1 0]
#    absolutely:      -2.20
# word: stereotypical, score: [0 1 0 0 0]
# stereotypical:       2.25
# word: predictable, score: [0 1 0 0 0]
#   predictable:       1.15
# word: little, score: [0 0 1 0 0]
#        little:       0.41
# word: a, score: [0 0 1 0 0]
#             a:       0.05
# word: ., score: [0 0 1 0 0]
#             .:      -0.11
# word: b-movie, score: [0 1 0 0 0]
#       b-movie:      -0.17
# word: and, score: [0 0 1 0 0]
#           and:      -0.17
# word: but, score: [0 0 1 0 0]
#           but:       0.24
# word: he, score: [0 0 1 0 0]
#            he:       0.10
# word: somehow, score: [0 0 1 0 0]
#       somehow:       0.09
# word: off, score: [0 1 0 0 0]
#           off:       0.07
# word: pulls, score: [0 0 1 0 0]
#         pulls:       0.01
# word: ., score: [0 0 1 0 0]
#             .:      -0.04
# word: it, score: [0 0 1 0 0]
#            it:      -0.05
# word: pretension, score: [0 0 1 0 0]
#    pretension:       0.65
# word: heavy-handed, score: [0 1 0 0 0]
#  heavy-handed:       0.49
# word: literary, score: [0 0 1 0 0]
#      literary:       0.30
# word: exercise, score: [0 0 1 0 0]
#      exercise:       0.23
# word: in, score: [0 0 1 0 0]
#            in:       0.01
# word: ., score: [0 0 1 0 0]
#             .:      -0.24
# word: time-vaulting, score: [0 0 1 0 0]
# time-vaulting:      -0.35
# word: mess, score: [0 1 0 0 0]
#          mess:       4.27
# word: unwieldy, score: [0 0 1 0 0]
#      unwieldy:       0.58
# word: ., score: [0 0 1 0 0]
#             .:       0.04
# word: of, score: [0 0 1 0 0]
#            of:       0.00
# word: bit, score: [0 0 1 0 0]
#           bit:      -0.02
# word: a, score: [0 0 1 0 0]
#             a:      -0.09
# word: an, score: [0 0 1 0 0]
#            an:      -0.20
# word: treat, score: [0 0 0 1 0]
#         treat:       3.06
# word: is, score: [0 0 1 0 0]
#            is:       0.28
# word: a, score: [0 0 1 0 0]
#             a:       0.26
# word: ., score: [0 0 1 0 0]
#             .:       0.23
# word: tosca, score: [0 0 1 0 0]
#         tosca:       0.23
# word: 's, score: [0 0 1 0 0]
#            's:       0.01
# word: jacquot, score: [0 0 1 0 0]
#       jacquot:      -1.23
# word: weight, score: [0 0 1 0 0]
#        weight:       1.48
# word: dead, score: [0 1 0 0 0]
#          dead:       0.77
# word: seems, score: [0 0 1 0 0]
#         seems:       0.15
# word: the, score: [0 0 1 0 0]
#           the:       0.00
# word: a, score: [0 0 1 0 0]
#             a:      -0.08
# word: ., score: [0 0 1 0 0]
#             .:      -0.29
# word: film, score: [0 0 1 0 0]
#          film:      -0.36
# word: mishmash, score: [0 1 0 0 0]
#      mishmash:       3.03
# word: uneasy, score: [0 1 0 0 0]
#        uneasy:       0.26
# word: of, score: [0 0 1 0 0]
#            of:       0.25
# word: ., score: [0 0 1 0 0]
#             .:      -0.28
# word: genres, score: [0 0 1 0 0]
#        genres:      -0.35
# word: styles, score: [0 0 1 0 0]
#        styles:      -0.47
# word: and, score: [0 0 1 0 0]
#           and:      -0.59
# word: captivating, score: [0 0 0 0 1]
#   captivating:       3.79
# word: comedy, score: [0 0 1 0 0]
#        comedy:       1.35
# word: manners, score: [0 0 1 0 0]
#       manners:       1.18
# word: cross-cultural, score: [0 0 1 0 0]
# cross-cultural:       0.77
# word: ., score: [0 0 1 0 0]
#             .:       0.47
# word: a, score: [0 0 1 0 0]
#             a:       0.24
# word: of, score: [0 0 1 0 0]
#            of:       0.04
# word: ?, score: [0 0 1 0 0]
#             ?:       0.97
# word: how, score: [0 0 1 0 0]
#           how:       0.48
# word: get, score: [0 0 1 0 0]
#           get:       0.13
# word: it, score: [0 0 1 0 0]
#            it:       0.00
# word: did, score: [0 0 1 0 0]
#           did:       0.00
# word: made, score: [0 0 1 0 0]
#          made:      -0.09
# word: ever, score: [0 0 1 0 0]
#          ever:      -0.28
# word: bad, score: [1 0 0 0 0]
#           bad:       1.09
# word: not, score: [0 1 0 0 0]
#           not:       0.97
# word: at, score: [0 0 1 0 0]
#            at:       0.04
# word: all, score: [0 0 1 0 0]
#           all:      -0.04
# word: a, score: [0 0 1 0 0]
#             a:      -0.05
# word: ., score: [0 0 1 0 0]
#             .:      -0.20
# word: journey, score: [0 0 1 0 0]
#       journey:      -0.40
# word: it, score: [0 0 1 0 0]
#            it:       0.25
# word: shows, score: [0 0 1 0 0]
#         shows:       0.25
# word: ., score: [0 0 1 0 0]
#             .:       0.16
# word: tells, score: [0 0 1 0 0]
#         tells:       0.12
# word: more, score: [0 0 1 0 0]
#          more:       0.09
# word: it, score: [0 0 1 0 0]
#            it:       0.03
# word: than, score: [0 0 1 0 0]
#          than:      -0.08
# word: full, score: [0 0 0 1 0]
#          full:       0.18
# word: this, score: [0 0 1 0 0]
#          this:       0.09
# word: is, score: [0 0 1 0 0]
#            is:       0.03
# word: rabbits, score: [0 0 1 0 0]
#       rabbits:      -0.02
# word: film, score: [0 0 1 0 0]
#          film:      -0.04
# word: ., score: [0 0 1 0 0]
#             .:      -0.05
# word: of, score: [0 0 1 0 0]
#            of:      -0.15
# word: fiction, score: [0 0 0 1 0]
#       fiction:       0.56
# word: a, score: [0 0 1 0 0]
#             a:       0.26
# word: average, score: [0 0 1 0 0]
#       average:       0.13
# word: ., score: [0 0 1 0 0]
#             .:       0.11
# word: very, score: [0 0 1 0 0]
#          very:      -0.07
# word: science, score: [0 0 1 0 0]
#       science:      -0.12
# word: film, score: [0 0 1 0 0]
#          film:      -0.22
# word: inviting, score: [0 0 0 1 0]
#      inviting:       3.26
# word: piece, score: [0 0 1 0 0]
#         piece:       1.55
# word: film, score: [0 0 1 0 0]
#          film:       1.35
# word: ., score: [0 0 1 0 0]
#             .:       0.48
# word: an, score: [0 0 1 0 0]
#            an:       0.34
# word: ..., score: [0 0 1 0 0]
#           ...:       0.16
# word: of, score: [0 0 1 0 0]
#            of:       0.06
# word: too, score: [0 1 0 0 0]
#           too:       2.66
# word: own, score: [0 0 1 0 0]
#           own:       0.29
# word: its, score: [0 0 1 0 0]
#           its:       0.06
# word: for, score: [0 0 1 0 0]
#           for:       0.05
# word: ., score: [0 0 1 0 0]
#             .:      -0.16
# word: simple, score: [0 0 1 0 0]
#        simple:      -0.81
# word: good, score: [0 0 0 1 0]
#          good:      -1.82
# word: wins, score: [0 0 0 0 1]
#          wins:       3.11
# word: you, score: [0 0 1 0 0]
#           you:       1.73
# word: ., score: [0 0 1 0 0]
#             .:       0.53
# word: it, score: [0 0 1 0 0]
#            it:       0.23
# word: ,, score: [0 0 1 0 0]
#             ,:       0.09
# word: eventually, score: [0 0 1 0 0]
#    eventually:      -0.02
# word: over, score: [0 0 1 0 0]
#          over:      -0.54
# word: overstuffed, score: [0 1 0 0 0]
#   overstuffed:       2.74
# word: teen-catholic-movie, score: [0 0 1 0 0]
# teen-catholic-movie:       0.76
# word: of, score: [0 0 1 0 0]
#            of:       0.08
# word: an, score: [0 0 1 0 0]
#            an:       0.02
# word: dogma, score: [0 0 1 0 0]
#         dogma:      -0.17
# word: ., score: [0 0 1 0 0]
#             .:      -0.29
# word: compendium, score: [0 0 1 0 0]
#    compendium:      -0.85
# word: barely, score: [0 1 0 0 0]
#        barely:       1.50
# word: book, score: [0 0 1 0 0]
#          book:       1.05
# word: goes, score: [0 0 1 0 0]
#          goes:       0.40
# word: beyond, score: [0 0 1 0 0]
#        beyond:       0.19
# word: ., score: [0 0 1 0 0]
#             .:      -0.22
# word: comic, score: [0 0 1 0 0]
#         comic:      -0.66
# word: status, score: [0 0 0 1 0]
#        status:      -1.88
# word: ?, score: [0 0 1 0 0]
#             ?:       1.28
# word: green, score: [0 0 1 0 0]
#         green:       0.13
# word: or, score: [0 0 1 0 0]
#            or:       0.09
# word: tom, score: [0 0 1 0 0]
#           tom:       0.05
# word: as, score: [0 0 1 0 0]
#            as:       0.01
# word: han, score: [0 0 1 0 0]
#           han:      -0.08
# word: solo, score: [0 0 0 1 0]
#          solo:      -0.44
# word: boring, score: [1 0 0 0 0]
#        boring:       4.05
# word: godawful, score: [0 0 1 0 0]
#      godawful:       0.20
# word: of, score: [0 0 1 0 0]
#            of:       0.18
# word: movie, score: [0 0 1 0 0]
#         movie:      -0.21
# word: slug, score: [0 0 1 0 0]
#          slug:      -0.46
# word: ., score: [0 0 1 0 0]
#             .:      -0.51
# word: a, score: [0 0 1 0 0]
#             a:      -0.53
# word: all, score: [0 0 1 0 0]
#           all:       0.28
# word: is, score: [0 0 1 0 0]
#            is:       0.10
# word: fuhgeddaboutit, score: [0 0 1 0 0]
# fuhgeddaboutit:       0.05
# word: say, score: [0 0 1 0 0]
#           say:       0.03
# word: ., score: [0 0 1 0 0]
#             .:       0.03
# word: can, score: [0 0 1 0 0]
#           can:       0.02
# word: i, score: [0 0 1 0 0]
#             i:       0.01
# word: wonderfully, score: [0 0 0 0 1]
#   wonderfully:       3.62
# word: hilarious, score: [0 0 0 0 1]
#     hilarious:       2.77
# word: touching, score: [0 0 0 1 0]
#      touching:       2.17
# word: dyspeptic, score: [0 0 1 0 0]
#     dyspeptic:       0.74
# word: ., score: [0 0 1 0 0]
#             .:       0.70
# word: and, score: [0 0 1 0 0]
#           and:       0.52
# word: ,, score: [0 0 1 0 0]
#             ,:       0.12
# word: not, score: [0 1 0 0 0]
#           not:       1.55
# word: might, score: [0 0 1 0 0]
#         might:       0.03
# word: buy, score: [0 0 1 0 0]
#           buy:       0.02
# word: the, score: [0 0 1 0 0]
# ...
#          alas:      -0.01
# word: the, score: [0 0 1 0 0]
#           the:      -0.01
# word: play, score: [0 0 1 0 0]
#          play:      -0.02
# word: ,, score: [0 0 1 0 0]
#             ,:      -0.02
# word: santa, score: [0 0 1 0 0]
#         santa:      -0.03
# word: meltdown, score: [0 0 1 0 0]
#      meltdown:      -0.04
# word: ..., score: [0 0 1 0 0]
#           ...:      -0.05
# word: -rrb-, score: [0 0 1 0 0]
#         -rrb-:      -0.06
# word: the, score: [0 0 1 0 0]
#           the:      -0.06
# word: gets, score: [0 0 1 0 0]
#          gets:      -0.07
# word: is, score: [0 0 1 0 0]
#            is:      -0.09
# word: -lrb-, score: [0 0 1 0 0]
#         -lrb-:      -0.10
# word: a, score: [0 0 1 0 0]
#             a:      -0.11
# word: it, score: [0 0 1 0 0]
#            it:      -0.14
# word: ideas, score: [0 0 1 0 0]
#         ideas:      -0.14
# word: has, score: [0 0 1 0 0]
#           has:      -0.15
# word: a, score: [0 0 1 0 0]
#             a:      -0.16
# word: is, score: [0 0 1 0 0]
#            is:      -0.16
# word: and, score: [0 0 1 0 0]
#           and:      -0.19
# word: and, score: [0 0 1 0 0]
#           and:      -0.20
# word: ., score: [0 0 1 0 0]
#             .:      -0.24
# word: film, score: [0 0 1 0 0]
#          film:      -0.35
# word: has, score: [0 0 1 0 0]
#           has:      -0.39
# word: charm, score: [0 0 0 1 0]
#         charm:      -0.79
# word: modest, score: [0 0 0 1 0]
#        modest:      -1.02
# word: cute, score: [0 0 0 1 0]
#          cute:      -1.94
# word: rotten, score: [0 1 0 0 0]
#        rotten:       1.15
# word: trouble, score: [0 1 0 0 0]
#       trouble:       0.68
# word: pulp, score: [0 0 1 0 0]
#          pulp:       0.40
# word: mouth, score: [0 0 1 0 0]
#         mouth:       0.17
# word: n't, score: [0 1 0 0 0]
#           n't:       0.17
# word: if, score: [0 0 1 0 0]
#            if:       0.11
# word: coming, score: [0 0 1 0 0]
#        coming:       0.07
# word: a, score: [0 0 1 0 0]
#             a:       0.03
# word: on, score: [0 0 1 0 0]
#            on:       0.02
# word: biting, score: [0 0 1 0 0]
#        biting:       0.01
# word: of, score: [0 0 1 0 0]
#            of:       0.01
# word: ,, score: [0 0 1 0 0]
#             ,:       0.01
# word: your, score: [0 0 1 0 0]
#          your:       0.01
# word: hot, score: [0 1 0 0 0]
#           hot:       0.01
# word: is, score: [0 0 1 0 0]
#            is:       0.01
# word: living, score: [0 0 1 0 0]
#        living:       0.01
# word: like, score: [0 0 1 0 0]
#          like:       0.01
# word: like, score: [0 0 1 0 0]
#          like:       0.01
# word: least, score: [0 1 0 0 0]
#         least:       0.01
# word: know, score: [0 0 1 0 0]
#          know:       0.01
# word: a, score: [0 0 1 0 0]
#             a:       0.01
# word: ,, score: [0 0 1 0 0]
#             ,:       0.00
# word: coming, score: [0 0 1 0 0]
#        coming:       0.00
# word: what, score: [0 0 1 0 0]
#          what:       0.00
# word: at, score: [0 0 1 0 0]
#            at:       0.00
# word: into, score: [0 0 1 0 0]
#          into:       0.00
# word: 's, score: [0 0 1 0 0]
#            's:      -0.00
# word: do, score: [0 0 1 0 0]
#            do:      -0.00
# word: day, score: [0 0 1 0 0]
#           day:      -0.00
# word: what, score: [0 0 1 0 0]
#          what:      -0.01
# word: looks, score: [0 0 1 0 0]
#         looks:      -0.01
# word: day, score: [0 0 1 0 0]
#           day:      -0.01
# word: plum, score: [0 0 1 0 0]
#          plum:      -0.01
# word: worms, score: [0 0 1 0 0]
#         worms:      -0.03
# word: and, score: [0 0 1 0 0]
#           and:      -0.03
# word: with, score: [0 0 1 0 0]
#          with:      -0.05
# word: ,, score: [0 0 1 0 0]
#             ,:      -0.06
# word: away, score: [0 0 1 0 0]
#          away:      -0.10
# word: summer, score: [0 0 1 0 0]
#        summer:      -0.11
# word: you, score: [0 0 1 0 0]
#           you:      -0.11
# word: every, score: [0 0 1 0 0]
#         every:      -0.12
# word: and, score: [0 0 1 0 0]
#           and:      -0.13
# word: ., score: [0 0 1 0 0]
#             .:      -0.16
# word: full, score: [0 0 0 1 0]
#          full:      -0.17
# word: watching, score: [0 0 1 0 0]
#      watching:      -0.17
# word: juicy, score: [0 0 0 1 0]
#         juicy:      -0.19
# word: delicious, score: [0 0 0 1 0]
#     delicious:      -0.43
# word: commanding, score: [0 0 0 1 0]
#    commanding:       5.48
# word: faithful, score: [0 0 0 1 0]
#      faithful:       2.69
# word: open, score: [0 0 0 1 0]
#          open:       1.72
# word: and, score: [0 0 1 0 0]
#           and:       0.80
# word: it, score: [0 0 1 0 0]
#            it:       0.65
# word: vision, score: [0 0 1 0 0]
#        vision:       0.51
# word: glories, score: [0 0 1 0 0]
#       glories:       0.46
# word: leave, score: [0 0 0 0 1]
#         leave:       0.37
# word: is, score: [0 0 1 0 0]
#            is:       0.35
# word: both, score: [0 0 1 0 0]
#          both:       0.23
# word: service, score: [0 0 1 0 0]
#       service:       0.21
# word: way, score: [0 0 1 0 0]
#           way:       0.21
# word: 82, score: [0 0 1 0 0]
#            82:       0.21
# word: two, score: [0 0 1 0 0]
#           two:       0.17
# word: ., score: [0 0 1 0 0]
#             .:       0.17
# word: a, score: [0 0 1 0 0]
#             a:       0.16
# word: the, score: [0 0 1 0 0]
#           the:       0.13
# word: a, score: [0 0 1 0 0]
#             a:       0.08
# word: it, score: [0 0 1 0 0]
#            it:       0.05
# word: bend, score: [0 0 1 0 0]
#          bend:       0.05
# word: ,, score: [0 0 1 0 0]
#             ,:       0.04
# word: rohmer, score: [0 0 1 0 0]
#        rohmer:       0.04
# word: that, score: [0 0 1 0 0]
#          that:       0.04
# word: the, score: [0 0 1 0 0]
#           the:       0.04
# word: ,, score: [0 0 1 0 0]
#             ,:       0.03
# word: as, score: [0 0 1 0 0]
#            as:       0.03
# word: of, score: [0 0 1 0 0]
#            of:       0.03
# word: the, score: [0 0 1 0 0]
#           the:       0.02
# word: to, score: [0 0 1 0 0]
#            to:       0.02
# word: of, score: [0 0 1 0 0]
#            of:       0.02
# word: current, score: [0 0 1 0 0]
#       current:       0.01
# word: to, score: [0 0 1 0 0]
#            to:       0.00
# word: to, score: [0 0 1 0 0]
#            to:       0.00
# word: find, score: [0 0 1 0 0]
#          find:      -0.02
# word: technique, score: [0 0 1 0 0]
#     technique:      -0.03
# word: to, score: [0 0 1 0 0]
#            to:      -0.04
# word: now, score: [0 0 1 0 0]
#           now:      -0.04
# word: to, score: [0 0 1 0 0]
#            to:      -0.04
# word: past, score: [0 0 1 0 0]
#          past:      -0.11
# word: than, score: [0 0 1 0 0]
#          than:      -0.21
# word: was, score: [0 0 1 0 0]
#           was:      -0.27
# word: architectural, score: [0 0 1 0 0]
# architectural:      -0.41
# word: city, score: [0 0 1 0 0]
#          city:      -0.42
# word: spaces, score: [0 0 0 1 0]
#        spaces:      -0.43
# word: of, score: [0 0 1 0 0]
#            of:      -0.45
# word: more, score: [0 0 1 0 0]
#          more:      -0.66
# word: ago, score: [0 0 1 0 0]
#           ago:      -1.12
# word: centuries, score: [0 0 1 0 0]
#     centuries:      -1.99
# word: fresh, score: [0 0 0 0 1]
#         fresh:       4.94
# word: thriller, score: [0 0 0 1 0]
#      thriller:       2.56
# word: free, score: [0 0 0 1 0]
#          free:       2.42
# word: first, score: [0 0 1 0 0]
#         first:       1.57
# word: charm, score: [0 0 0 1 0]
#         charm:       1.55
# word: so, score: [0 0 1 0 0]
#            so:       1.06
# word: time, score: [0 0 1 0 0]
#          time:       0.92
# word: and, score: [0 0 1 0 0]
#           and:       0.81
# word: it, score: [0 0 1 0 0]
#            it:       0.76
# word: nostalgic, score: [0 0 0 1 0]
#     nostalgic:       0.48
# word: is, score: [0 0 1 0 0]
#            is:       0.45
# word: ., score: [0 0 1 0 0]
#             .:       0.44
# word: happening, score: [0 0 1 0 0]
#     happening:       0.44
# word: the, score: [0 0 1 0 0]
#           the:       0.38
# word: sensibility, score: [0 0 1 0 0]
#   sensibility:       0.32
# word: and, score: [0 0 1 0 0]
#           and:       0.32
# word: usual, score: [0 0 1 0 0]
#         usual:       0.24
# word: exudes, score: [0 0 0 1 0]
#        exudes:       0.22
# word: ,, score: [0 0 1 0 0]
#             ,:       0.19
# word: time, score: [0 0 1 0 0]
#          time:       0.17
# word: and, score: [0 0 1 0 0]
#           and:       0.13
# word: the, score: [0 0 1 0 0]
#           the:       0.09
# word: ,, score: [0 0 1 0 0]
#             ,:       0.09
# word: kind, score: [0 0 0 1 0]
#          kind:       0.08
# word: the, score: [0 0 1 0 0]
#           the:       0.04
# word: all, score: [0 0 1 0 0]
#           all:       0.04
# word: familiar, score: [0 0 1 0 0]
#      familiar:       0.04
# word: it, score: [0 0 1 0 0]
#            it:       0.03
# word: a, score: [0 0 1 0 0]
#             a:       0.03
# word: ,, score: [0 0 1 0 0]
#             ,:       0.02
# word: its, score: [0 0 1 0 0]
#           its:       0.01
# word: but, score: [0 0 1 0 0]
#           but:       0.00
# word: of, score: [0 0 1 0 0]
#            of:       0.00
# word: scenes, score: [0 0 1 0 0]
#        scenes:      -0.01
# word: are, score: [0 0 1 0 0]
#           are:      -0.01
# word: than, score: [0 0 1 0 0]
#          than:      -0.02
# word: all, score: [0 0 1 0 0]
#           all:      -0.02
# word: at, score: [0 0 1 0 0]
#            at:      -0.03
# word: to, score: [0 0 1 0 0]
#            to:      -0.03
# word: more, score: [0 0 1 0 0]
#          more:      -0.03
# word: of, score: [0 0 1 0 0]
#            of:      -0.09
# word: that, score: [0 0 1 0 0]
#          that:      -0.11
# word: spy-movie, score: [0 0 1 0 0]
#     spy-movie:      -0.20
# word: for, score: [0 0 1 0 0]
#           for:      -0.32
# word: same, score: [0 0 1 0 0]
#          same:      -0.35
# word: be, score: [0 0 1 0 0]
#            be:      -0.51
# word: seems, score: [0 0 1 0 0]
#         seems:      -0.53
# word: nonsense, score: [0 1 0 0 0]
#      nonsense:      -6.61
# word: less, score: [0 0 1 0 0]
#          less:       0.46
# word: coherence, score: [0 0 1 0 0]
#     coherence:       0.45
# word: need, score: [0 0 1 0 0]
#          need:       0.22
# word: only, score: [0 0 1 0 0]
#          only:       0.18
# word: feels, score: [0 0 1 0 0]
#         feels:       0.16
# word: reading, score: [0 0 1 0 0]
#       reading:       0.14
# word: script, score: [0 0 1 0 0]
#        script:       0.12
# word: deniro, score: [0 0 1 0 0]
#        deniro:       0.10
# word: polishing, score: [0 0 1 0 0]
#     polishing:       0.06
# word: sentimentality, score: [0 0 1 0 0]
# sentimentality:       0.05
# word: furious, score: [0 1 0 0 0]
#       furious:       0.04
# word: than, score: [0 0 1 0 0]
#          than:       0.03
# word: toward, score: [0 0 1 0 0]
#        toward:       0.02
# word: of, score: [0 0 1 0 0]
#            of:       0.01
# word: to, score: [0 0 1 0 0]
#            to:       0.01
# word: underscores, score: [0 0 1 0 0]
#   underscores:       0.01
# word: which, score: [0 0 1 0 0]
#         which:       0.00
# word: plods, score: [0 0 1 0 0]
#         plods:       0.00
# word: of, score: [0 0 1 0 0]
#            of:       0.00
# word: of, score: [0 0 1 0 0]
#            of:       0.00
# word: the, score: [0 0 1 0 0]
#           the:      -0.00
# word: in, score: [0 0 1 0 0]
#            in:      -0.00
# word: as, score: [0 0 1 0 0]
#            as:      -0.00
# word: the, score: [0 0 1 0 0]
#           the:      -0.00
# word: the, score: [0 0 1 0 0]
#           the:      -0.01
# word: the, score: [0 0 1 0 0]
#           the:      -0.01
# word: ,, score: [0 0 1 0 0]
#             ,:      -0.02
# word: end, score: [0 0 1 0 0]
#           end:      -0.02
# word: that, score: [0 0 1 0 0]
#          that:      -0.02
# word: like, score: [0 0 1 0 0]
#          like:      -0.02
# word: ,, score: [0 0 1 0 0]
#             ,:      -0.02
# word: movie, score: [0 0 1 0 0]
#         movie:      -0.03
# word: part, score: [0 0 1 0 0]
#          part:      -0.03
# word: ,, score: [0 0 1 0 0]
#             ,:      -0.03
# word: like, score: [0 0 1 0 0]
#          like:      -0.03
# word: a, score: [0 0 1 0 0]
#             a:      -0.03
# word: a, score: [0 0 1 0 0]
#             a:      -0.04
# word: filmed, score: [0 0 1 0 0]
#        filmed:      -0.04
# word: itself, score: [0 0 1 0 0]
#        itself:      -0.05
# word: the, score: [0 0 1 0 0]
#           the:      -0.06
# word: it, score: [0 0 1 0 0]
#            it:      -0.06
# word: movie, score: [0 0 1 0 0]
#         movie:      -0.08
# word: this, score: [0 0 1 0 0]
#          this:      -0.11
# word: -lrb-, score: [0 0 1 0 0]
#         -lrb-:      -0.11
# word: ., score: [0 0 1 0 0]
#             .:      -0.15
# word: -rrb-, score: [0 0 1 0 0]
#         -rrb-:      -0.24
# word: fuzzy, score: [0 0 0 1 0]
#         fuzzy:      -0.46
# word: brings, score: [0 0 0 1 0]
#        brings:      -0.47
# word: no, score: [0 1 0 0 0]
#            no:       2.21
# word: idea, score: [0 0 1 0 0]
#          idea:       0.65
# word: book, score: [0 0 1 0 0]
#          book:       0.50
# word: no, score: [0 1 0 0 0]
#            no:       0.44
# word: but, score: [0 0 1 0 0]
#           but:       0.16
# word: matter, score: [0 0 1 0 0]
#        matter:       0.15
# word: old, score: [0 0 1 0 0]
#           old:       0.14
# word: backs, score: [0 0 1 0 0]
#         backs:       0.11
# word: commodity, score: [0 0 1 0 0]
#     commodity:       0.09
# word: were, score: [0 0 1 0 0]
#          were:       0.09
# word: to, score: [0 0 1 0 0]
#            to:       0.07
# word: fleeting, score: [0 0 1 0 0]
#      fleeting:       0.06
# word: are, score: [0 0 1 0 0]
#           are:       0.05
# word: who, score: [0 0 1 0 0]
#           who:       0.04
# word: age, score: [0 0 1 0 0]
#           age:       0.02
# word: at, score: [0 0 1 0 0]
#            at:       0.01
# word: who, score: [0 0 1 0 0]
#           who:       0.01
# word: that, score: [0 0 1 0 0]
#          that:       0.00
# word: on, score: [0 0 1 0 0]
#            on:       0.00
# word: ;, score: [0 0 1 0 0]
#             ;:       0.00
# word: have, score: [0 0 1 0 0]
#          have:      -0.00
# word: of, score: [0 0 1 0 0]
#            of:      -0.00
# word: are, score: [0 0 1 0 0]
#           are:      -0.00
# word: what, score: [0 0 1 0 0]
#          what:      -0.01
# word: are, score: [0 0 1 0 0]
#           are:      -0.02
# word: time, score: [0 0 1 0 0]
#          time:      -0.02
# word: a, score: [0 0 1 0 0]
#             a:      -0.03
# word: ,, score: [0 0 1 0 0]
#             ,:      -0.04
# word: the, score: [0 0 1 0 0]
#           the:      -0.04
# word: is, score: [0 0 1 0 0]
#            is:      -0.05
# word: they, score: [0 0 1 0 0]
#          they:      -0.05
# word: 's, score: [0 0 1 0 0]
#            's:      -0.06
# word: the, score: [0 0 1 0 0]
#           the:      -0.06
# word: the, score: [0 0 1 0 0]
#           the:      -0.08
# word: that, score: [0 0 1 0 0]
#          that:      -0.08
# word: we, score: [0 0 1 0 0]
#            we:      -0.10
# word: and, score: [0 0 1 0 0]
#           and:      -0.11
# word: we, score: [0 0 1 0 0]
#            we:      -0.12
# word: and, score: [0 0 1 0 0]
#           and:      -0.12
# word: become, score: [0 0 1 0 0]
#        become:      -0.12
# word: our, score: [0 0 1 0 0]
#           our:      -0.17
# word: we, score: [0 0 1 0 0]
#            we:      -0.20
# word: --, score: [0 0 1 0 0]
#            --:      -0.20
# word: how, score: [0 0 1 0 0]
#           how:      -0.25
# word: ., score: [0 0 1 0 0]
#             .:      -0.27
# word: parents, score: [0 0 1 0 0]
#       parents:      -0.29
# word: our, score: [0 0 1 0 0]
#           our:      -0.30
# word: is, score: [0 0 1 0 0]
#            is:      -0.34
# word: film, score: [0 0 1 0 0]
#          film:      -0.37
# word: twin, score: [0 0 1 0 0]
#          twin:      -0.40
# word: one, score: [0 0 1 0 0]
#           one:      -0.41
# word: premises, score: [0 0 1 0 0]
#      premises:      -0.41
# word: precious, score: [0 0 0 1 0]
#      precious:      -0.45
# word: you, score: [0 0 1 0 0]
#           you:      -0.52
# word: presumes, score: [0 0 0 1 0]
#      presumes:      -1.19
# word: faithful, score: [0 0 0 1 0]
#      faithful:      -2.97
# zero_to_zero:152
# zero_to_one:188
# zero_to_two:37
# zero_to_three:1
# zero_to_four:0
# one_to_zero:124
# one_to_one:486
# one_to_two:173
# one_to_three:1
# one_to_four:0
# two_to_zero:0
# two_to_one:4
# two_to_two:101
# two_to_three:2
# two_to_four:0
# three_to_zero:0
# three_to_one:0
# three_to_two:125
# three_to_three:314
# three_to_four:68
# four_to_zero:0
# four_to_one:0
# four_to_two:115
# four_to_three:163
# four_to_four:156
# weighted_correct_count:1209
# weighted_n_to_p:2
# weighted_p_to_n:0
# weighted_neutral_floating_1:6
